# %%
from owlready2 import *

# %%
onto = get_ontology("../ontology_file/apu_owl.owx").load()
# Out:
# * Owlready2 * WARNING: AnnotationProperty http://www.semanticweb.org/nipun_qk4hy9e/ontologies/2025/5/apuf/columnOfTable belongs to more than one entity types: [owl.ObjectProperty, owl.AnnotationProperty]; I'm trying to fix it...
# * Owlready2 * WARNING: AnnotationProperty http://www.semanticweb.org/nipun_qk4hy9e/ontologies/2025/5/apuf/ColumnName belongs to more than one entity types: [owl.DatatypeProperty, owl.AnnotationProperty]; I'm trying to fix it...
# * Owlready2 * WARNING: AnnotationProperty http://www.semanticweb.org/nipun_qk4hy9e/ontologies/2025/5/apuf/TableName belongs to more than one entity types: [owl.DatatypeProperty, owl.AnnotationProperty]; I'm trying to fix it...
