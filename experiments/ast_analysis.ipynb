# %%
from sqlglot import parse_one

# %% [markdown]
# ### Read queries

# %%
query = "SELECT first_name, last_name, salary FROM employees WHERE salary > 3800;"
print(repr(parse_one(query)))
# Out:
# Select(
#   expressions=[
#     Column(
#       this=Identifier(this=first_name, quoted=False)),
#     Column(
#       this=Identifier(this=last_name, quoted=False)),
#     Column(
#       this=Identifier(this=salary, quoted=False))],
#   from=From(
#     this=Table(
#       this=Identifier(this=employees, quoted=False))),
#   where=Where(
#     this=GT(
#       this=Column(
#         this=Identifier(this=salary, quoted=False)),
#       expression=Literal(this=3800, is_string=False))))

# %%
# join example
query = "SELECT table1.column1,table1.column2,table2.column1 FROM table1 LEFT JOIN table2 ON table1.matching_column = table2.matching_column;"
print(repr(parse_one(query)))
# Out:
# Select(
#   expressions=[
#     Column(
#       this=Identifier(this=column1, quoted=False),
#       table=Identifier(this=table1, quoted=False)),
#     Column(
#       this=Identifier(this=column2, quoted=False),
#       table=Identifier(this=table1, quoted=False)),
#     Column(
#       this=Identifier(this=column1, quoted=False),
#       table=Identifier(this=table2, quoted=False))],
#   from=From(
#     this=Table(
#       this=Identifier(this=table1, quoted=False))),
#   joins=[
#     Join(
#       this=Table(
#         this=Identifier(this=table2, quoted=False)),
#       side=LEFT,
#       on=EQ(
#         this=Column(
#           this=Identifier(this=matching_column, quoted=False),
#           table=Identifier(this=table1, quoted=False)),
#         expression=Column(
#           this=Identifier(this=matching_column, quoted=False),
#           table=Identifier(this=table2, quoted=False))))])

# %%
# exists syntax use 
query = "SELECT * FROM employees WHERE EXISTS (SELECT * FROM departments WHERE employees.department_id = departments.id);"
print(repr(parse_one(query)))
# Out:
# Select(
#   expressions=[
#     Star()],
#   from=From(
#     this=Table(
#       this=Identifier(this=employees, quoted=False))),
#   where=Where(
#     this=Exists(
#       this=Select(
#         expressions=[
#           Star()],
#         from=From(
#           this=Table(
#             this=Identifier(this=departments, quoted=False))),
#         where=Where(
#           this=EQ(
#             this=Column(
#               this=Identifier(this=department_id, quoted=False),
#               table=Identifier(this=employees, quoted=False)),
#             expression=Column(
#               this=Identifier(this=id, quoted=False),
#               table=Identifier(this=departments, quoted=False))))))))

# %%
# between syntax use
query = "SELECT * FROM employees WHERE salary BETWEEN 3000 AND 5000;"
print(repr(parse_one(query)))
# Out:
# Select(
#   expressions=[
#     Star()],
#   from=From(
#     this=Table(
#       this=Identifier(this=employees, quoted=False))),
#   where=Where(
#     this=Between(
#       this=Column(
#         this=Identifier(this=salary, quoted=False)),
#       low=Literal(this=3000, is_string=False),
#       high=Literal(this=5000, is_string=False))))

# %%
# like syntax use
query = "SELECT * FROM employees WHERE first_name LIKE 'A%';"
print(repr(parse_one(query)))
# Out:
# Select(
#   expressions=[
#     Star()],
#   from=From(
#     this=Table(
#       this=Identifier(this=employees, quoted=False))),
#   where=Where(
#     this=Like(
#       this=Column(
#         this=Identifier(this=first_name, quoted=False)),
#       expression=Literal(this='A%', is_string=True))))

# %%
# in syntax use
query = "SELECT * FROM employees WHERE department_id IN (1, 2, 3);"
print(repr(parse_one(query)))
# Out:
# Select(
#   expressions=[
#     Star()],
#   from=From(
#     this=Table(
#       this=Identifier(this=employees, quoted=False))),
#   where=Where(
#     this=In(
#       this=Column(
#         this=Identifier(this=department_id, quoted=False)),
#       expressions=[
#         Literal(this=1, is_string=False),
#         Literal(this=2, is_string=False),
#         Literal(this=3, is_string=False)])))

# %%
# wildcard with join syntax use
query = "SELECT * FROM employees e JOIN departments d ON e.department_id = d.id WHERE d.department_name LIKE 'Sales%';"
print(repr(parse_one(query)))
# Out:
# Select(
#   expressions=[
#     Star()],
#   from=From(
#     this=Table(
#       this=Identifier(this=employees, quoted=False),
#       alias=TableAlias(
#         this=Identifier(this=e, quoted=False)))),
#   joins=[
#     Join(
#       this=Table(
#         this=Identifier(this=departments, quoted=False),
#         alias=TableAlias(
#           this=Identifier(this=d, quoted=False))),
#       on=EQ(
#         this=Column(
#           this=Identifier(this=department_id, quoted=False),
#           table=Identifier(this=e, quoted=False)),
#         expression=Column(
#           this=Identifier(this=id, quoted=False),
#           table=Identifier(this=d, quoted=False))))],
#   where=Where(
#     this=Like(
#       this=Column(
#         this=Identifier(this=department_name, quoted=False),
#         table=Identifier(this=d, quoted=False)),
#       expression=Literal(this='Sales%', is_string=True))))

# %%
# simple group by syntax sample 
query = "SELECT department_id, COUNT(*) FROM employees GROUP BY department_id;"
print(repr(parse_one(query)))
# Out:
# Select(
#   expressions=[
#     Column(
#       this=Identifier(this=department_id, quoted=False)),
#     Count(
#       this=Star(),
#       big_int=True)],
#   from=From(
#     this=Table(
#       this=Identifier(this=employees, quoted=False))),
#   group=Group(
#     expressions=[
#       Column(
#         this=Identifier(this=department_id, quoted=False))]))

# %%
# order by syntax sample 
query = "SELECT first_name, last_name FROM employees ORDER BY last_name ASC;"
print(repr(parse_one(query)))
# Out:
# Select(
#   expressions=[
#     Column(
#       this=Identifier(this=first_name, quoted=False)),
#     Column(
#       this=Identifier(this=last_name, quoted=False))],
#   from=From(
#     this=Table(
#       this=Identifier(this=employees, quoted=False))),
#   order=Order(
#     expressions=[
#       Ordered(
#         this=Column(
#           this=Identifier(this=last_name, quoted=False)),
#         desc=False,
#         nulls_first=True)]))

# %% [markdown]
# ### Insert queries
