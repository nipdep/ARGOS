# %%
from copy import deepcopy

# %%
import sys 

sys.path.append("../")

# %%
from src import ASTPruner, ASTTreeOperator, SqlglotOperator, OntologyOperator, TreeNode

# %%
query = """SELECT l.loan_id, l.status FROM Loan l WHERE l.account_id IN (SELECT account_id FROM Account WHERE district_id = 'd002');"""

# %%
# query = "WITH AccountTransactions AS (SELECT a.account_id, a.frequency, t.type FROM Account a JOIN Transaction t ON a.account_id = t.account_id) SELECT * FROM AccountTransactions WHERE type = 'withdrawal';"

# %%
query = """
SELECT
    c.duration,
    c.date,
    (
        SELECT COUNT(*)
        FROM Order o
        WHERE o.account_id = c.account_id
    ) AS total_orders,
    (
        SELECT AVG(o2.amount)
        FROM Order o2
        WHERE o2.account_id = c.account_id
          AND o2.amount > 100
    ) AS avg_recent_order_amount
FROM Loan c
WHERE c.status = 'active';
"""

# %%
# query = """INSERT INTO "Loan" (loan_id, account_id, amount) VALUES ('l123', 'a456', 5000);"""

# %%
onto_path = "../ontology_file/aputv5e.rdf"
output_path = "../ontology_file/resolved_query_instances.rdf"
agent_id = "a0012"

# 1. Create an instance of the class
instantiator = OntologyOperator(onto_path)
# Out:
# table entities: {'Card': 't007', 'Disposition': 't005', 'District': 't008', 'Order': 't001', 'Transaction': 't002', 'Account': 't003', 'Loan': 't004', 'Client': 't006', 'xxxxx': 't00x'}
# column lookup: {('xxxxx', 'ooooo'): 'c00x', ('Card', 'type'): 'c026', ('Order', 'order_id'): 'c001', ('Order', 'account_to'): 'c004', ('Order', 'k_symbol'): 'c006', ('Transaction', 'trans_id'): 'c007', ('Loan', 'loan_id'): 'c016', ('Card', 'disp_id'): 'c020', ('Disposition', 'disp_id'): 'c020', ('Disposition', 'client_id'): 'c021', ('Client', 'client_id'): 'c021', ('Card', 'card_id'): 'c025', ('Transaction', 'k_symbol'): 'c032', ('Disposition', 'account_id'): 'c002', ('Order', 'account_id'): 'c002', ('Transaction', 'account_id'): 'c002', ('Account', 'account_id'): 'c002', ('Loan', 'account_id'): 'c002', ('Client', 'account_id'): 'c002', ('Order', 'amount'): 'c005', ('Transaction', 'date'): 'c008', ('Transaction', 'type'): 'c009', ('District', 'district_id'): 'c014', ('Account', 'district_id'): 'c014', ('Client', 'district_id'): 'c014', ('Transaction', 'amount'): 'c031', ('Account', 'date'): 'c033', ('Loan', 'date'): 'c034', ('Loan', 'amount'): 'c035', ('Order', 'bank_to'): 'c003', ('Transaction', 'operation'): 'c010', ('Transaction', 'balance'): 'c011', ('Transaction', 'bank'): 'c012', ('Transaction', 'account'): 'c013', ('Account', 'frequency'): 'c015', ('Loan', 'duration'): 'c017', ('Loan', 'payments'): 'c018', ('Loan', 'status'): 'c019', ('Disposition', 'type'): 'c022', ('Client', 'gender'): 'c023', ('Client', 'birth_date'): 'c024', ('Card', 'issued'): 'c027', ('District', 'name'): 'c028'}

# %%
query = """
WITH ClientAccounts AS (SELECT c.client_id, a.account_id FROM "Client" c JOIN "Disposition" d ON c.client_id = d.client_id JOIN "Account" a ON d.account_id = a.account_id) SELECT * FROM ClientAccounts;
 """

# %%
query = """
SELECT account, COUNT(type) AS types FROM Transaction WHERE account_id IN (SELECT account_id FROM Account WHERE district_id = 'd002');
"""

# %%
query = """
SELECT l.duration, COUNT(l.loan_id) as loan_count FROM "Client" c LEFT JOIN "Loan" l ON c.client_id = l.account_id GROUP BY c.client_id;
"""

# %%
# query = """
# SELECT l.* FROM "Loan" l WHERE l.account_id IN (SELECT a.account_id FROM "Account" a WHERE a.district_id = 1);
# """

sql_op = SqlglotOperator(query)
tree_op = ASTTreeOperator(sql_op)
# tree_op.pretty_print()
instantiator.instantiate_ontology(tree_op, agent_id)
tree_op.pretty_print()
# 3. Run the reasoner and save the ontology
instantiator.reason_and_save(output_path, save=True)
# Out:
# --> Instantiating ontology individuals...
# SELECT l.duration, COUNT(l.loan_id) AS loan_count FROM "Client" AS c LEFT JOIN "Loan" AS l ON c.client_id = l.account_id GROUP BY c.client_id
# Found 2 FROM/Join nodes in statement s4687e6.
# Initial in-context sources: {'Client': {'type': 'base_table', 'name': 'Client'}, 'c': {'type': 'base_table', 'name': 'Client'}, 'Loan': {'type': 'base_table', 'name': 'Loan'}, 'l': {'type': 'base_table', 'name': 'Loan'}}
# Resolving column 'duration' in context of table alias 'l' | context_sources: {'Client': {'type': 'base_table', 'name': 'Client'}, 'c': {'type': 'base_table', 'name': 'Client'}, 'Loan': {'type': 'base_table', 'name': 'Loan'}, 'l': {'type': 'base_table', 'name': 'Loan'}}
# Resolving column 'loan_id' in context of table alias 'l' | context_sources: {'Client': {'type': 'base_table', 'name': 'Client'}, 'c': {'type': 'base_table', 'name': 'Client'}, 'Loan': {'type': 'base_table', 'name': 'Loan'}, 'l': {'type': 'base_table', 'name': 'Loan'}}
# Resolving column 'client_id' in context of table alias 'c' | context_sources: {'Client': {'type': 'base_table', 'name': 'Client'}, 'c': {'type': 'base_table', 'name': 'Client'}, 'Loan': {'type': 'base_table', 'name': 'Loan'}, 'l': {'type': 'base_table', 'name': 'Loan'}}
# Resolving column 'account_id' in context of table alias 'l' | context_sources: {'Client': {'type': 'base_table', 'name': 'Client'}, 'c': {'type': 'base_table', 'name': 'Client'}, 'Loan': {'type': 'base_table', 'name': 'Loan'}, 'l': {'type': 'base_table', 'name': 'Loan'}}
# Resolving column 'client_id' in context of table alias 'c' | context_sources: {'Client': {'type': 'base_table', 'name': 'Client'}, 'c': {'type': 'base_table', 'name': 'Client'}, 'Loan': {'type': 'base_table', 'name': 'Loan'}, 'l': {'type': 'base_table', 'name': 'Loan'}}
#     - Instantiated 2 TableRefs and 5 ColumnRefs.
# └── <(s4687e6) Statement |  (SelectStatement) [remove=False]>
#     ├── <(n4687e6) Clause |  (SelectClause) [remove=False]>
#     │   ├── <(nb47aca) Expression |  (ColumnRef) [reftable=Loan, refcol=duration] [table_reference_id=t004] [column_reference_id=c017] [remove=False]>
#     │   └── <(n6c182f) Expression |  (Alias) [alias=loan_count] [remove=False]>
#     │       └── <(nd96abc) Expression |  (Function) [remove=False]>
#     │           └── <(n2ebac2) Expression |  (ColumnRef) [reftable=Loan, refcol=loan_id] [table_reference_id=t004] [column_reference_id=c016] [remove=False]>
#     ├── <(nb30975) Clause |  (FromClause) [remove=False]>
#     │   └── <(n733005) Expression |  (TableRef) [reftable=Client] [table_reference_id=t006] [remove=False] [refalias=c]>
#     ├── <(n047a9b) Clause |  (JoinClause) [remove=False]>
#     │   ├── <(n86341b) Expression |  (TableRef) [reftable=Loan] [table_reference_id=t004] [remove=False] [refalias=l]>
#     │   └── <(nb750f1) Expression |  (Operator) [remove=False] [logics=False] [value=c.client_id]>
#     │       ├── <(nf19373) Expression |  (ColumnRef) [reftable=Client, refcol=client_id] [table_reference_id=t006] [column_reference_id=c021] [remove=False]>
#     │       └── <(neb9651) Expression |  (ColumnRef) [reftable=Loan, refcol=account_id] [table_reference_id=t004] [column_reference_id=c002] [remove=False]>
#     └── <(n5153bc) Clause |  (GroupByClause) [remove=False]>
#         └── <(ne7efb9) Expression |  (ColumnRef) [reftable=Client, refcol=client_id] [table_reference_id=t006] [column_reference_id=c021] [remove=False]>
# --> Running reasoner and saving ontology...
# * Owlready2 * Running Pellet...
#     java -Xmx2000M -cp c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\antlr-3.2.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\antlr-runtime-3.2.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\aterm-java-1.6.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\commons-codec-1.6.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\httpclient-4.2.3.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\httpcore-4.2.2.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\jcl-over-slf4j-1.6.4.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\jena-arq-2.10.0.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\jena-core-2.10.0.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\jena-iri-0.9.5.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\jena-tdb-0.10.0.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\jgrapht-jdk1.5.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\log4j-1.2-api-2.19.0.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\log4j-api-2.19.0.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\log4j-core-2.19.0.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\owlapi-distribution-3.4.3-bin.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\pellet-2.3.1.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\slf4j-api-1.6.4.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\slf4j-log4j12-1.6.4.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\xercesImpl-2.10.0.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\xml-apis-1.4.01.jar pellet.Pellet realize --loader Jena --input-format N-Triples --infer-prop-values --ignore-imports C:\Users\NIPUN_~1\AppData\Local\Temp\tmpieonxawp
# * Owlready2 * Pellet took 3.2503106594085693 seconds
# * Owlready * (NB: only changes on entities loaded in Python are shown, other changes are done but not listed)
# * Owlready2 * Running Pellet...
#     java -Xmx2000M -cp c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\antlr-3.2.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\antlr-runtime-3.2.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\aterm-java-1.6.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\commons-codec-1.6.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\httpclient-4.2.3.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\httpcore-4.2.2.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\jcl-over-slf4j-1.6.4.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\jena-arq-2.10.0.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\jena-core-2.10.0.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\jena-iri-0.9.5.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\jena-tdb-0.10.0.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\jgrapht-jdk1.5.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\log4j-1.2-api-2.19.0.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\log4j-api-2.19.0.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\log4j-core-2.19.0.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\owlapi-distribution-3.4.3-bin.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\pellet-2.3.1.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\slf4j-api-1.6.4.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\slf4j-log4j12-1.6.4.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\xercesImpl-2.10.0.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\xml-apis-1.4.01.jar pellet.Pellet realize --loader Jena --input-format N-Triples --infer-prop-values --ignore-imports C:\Users\NIPUN_~1\AppData\Local\Temp\tmpa90zzj98
# * Owlready * Adding relation aputv5e.n2ebac2 hasParentNode aputv5e.nd96abc
# * Owlready * Adding relation aputv5e.n2ebac2 hasParentNode aputv5e.s4687e6
# * Owlready * Adding relation aputv5e.n2ebac2 hasParentNode aputv5e.n6c182f
# * Owlready * Adding relation aputv5e.n2ebac2 hasParentNode aputv5e.n4687e6
# * Owlready * Adding relation aputv5e.s4687e6 hasChildNode aputv5e.nf19373
# * Owlready * Adding relation aputv5e.s4687e6 hasChildNode aputv5e.n733005
# * Owlready * Adding relation aputv5e.s4687e6 hasChildNode aputv5e.n047a9b
# * Owlready * Adding relation aputv5e.s4687e6 hasChildNode aputv5e.n86341b
# * Owlready * Adding relation aputv5e.s4687e6 hasChildNode aputv5e.n6c182f
# * Owlready * Adding relation aputv5e.s4687e6 hasChildNode aputv5e.nb750f1
# * Owlready * Adding relation aputv5e.s4687e6 hasChildNode aputv5e.neb9651
# * Owlready * Adding relation aputv5e.s4687e6 hasChildNode aputv5e.nb47aca
# * Owlready * Adding relation aputv5e.s4687e6 hasChildNode aputv5e.n4687e6
# * Owlready * Adding relation aputv5e.s4687e6 hasChildNode aputv5e.n2ebac2
# * Owlready * Adding relation aputv5e.s4687e6 hasChildNode aputv5e.nb30975
# * Owlready * Adding relation aputv5e.s4687e6 hasChildNode aputv5e.nd96abc
# * Owlready * Adding relation aputv5e.s4687e6 hasChildNode aputv5e.n5153bc
# * Owlready * Adding relation aputv5e.s4687e6 hasChildNode aputv5e.ne7efb9
# * Owlready * Adding relation aputv5e.s4687e6 immediateChildNode aputv5e.n047a9b
# * Owlready * Adding relation aputv5e.s4687e6 immediateChildNode aputv5e.n5153bc
# * Owlready * Adding relation aputv5e.s4687e6 immediateChildNode aputv5e.n4687e6
# * Owlready * Adding relation aputv5e.s4687e6 immediateChildNode aputv5e.nb30975
# * Owlready * Adding relation aputv5e.nf19373 hasParentNode aputv5e.s4687e6
# * Owlready * Adding relation aputv5e.nf19373 hasParentNode aputv5e.n047a9b
# * Owlready * Adding relation aputv5e.nf19373 hasParentNode aputv5e.nb750f1
# * Owlready * Adding relation aputv5e.n047a9b hasParentNode aputv5e.s4687e6
# * Owlready * Adding relation aputv5e.n047a9b immediateParentNode aputv5e.s4687e6
# * Owlready * Adding relation aputv5e.n047a9b hasChildNode aputv5e.nf19373
# * Owlready * Adding relation aputv5e.n047a9b hasChildNode aputv5e.n86341b
# * Owlready * Adding relation aputv5e.n047a9b hasChildNode aputv5e.nb750f1
# * Owlready * Adding relation aputv5e.n047a9b hasChildNode aputv5e.neb9651
# * Owlready * Adding relation aputv5e.n047a9b immediateChildNode aputv5e.n86341b
# * Owlready * Adding relation aputv5e.n047a9b immediateChildNode aputv5e.nb750f1
# * Owlready * Adding relation aputv5e.nb750f1 hasParentNode aputv5e.s4687e6
# * Owlready * Adding relation aputv5e.nb750f1 hasParentNode aputv5e.n047a9b
# * Owlready * Adding relation aputv5e.nb750f1 immediateParentNode aputv5e.n047a9b
# * Owlready * Adding relation aputv5e.nb750f1 hasChildNode aputv5e.nf19373
# * Owlready * Adding relation aputv5e.nb750f1 hasChildNode aputv5e.neb9651
# * Owlready * Adding relation aputv5e.nd96abc hasParentNode aputv5e.s4687e6
# * Owlready * Adding relation aputv5e.nd96abc hasParentNode aputv5e.n6c182f
# * Owlready * Adding relation aputv5e.nd96abc hasParentNode aputv5e.n4687e6
# * Owlready * Adding relation aputv5e.nd96abc hasChildNode aputv5e.n2ebac2
# * Owlready * Adding relation aputv5e.ne7efb9 hasParentNode aputv5e.s4687e6
# * Owlready * Adding relation aputv5e.ne7efb9 hasParentNode aputv5e.n5153bc
# * Owlready * Adding relation aputv5e.ne7efb9 immediateParentNode aputv5e.n5153bc
# * Owlready * Adding relation aputv5e.neb9651 hasParentNode aputv5e.s4687e6
# * Owlready * Adding relation aputv5e.neb9651 hasParentNode aputv5e.n047a9b
# * Owlready * Adding relation aputv5e.neb9651 hasParentNode aputv5e.nb750f1
# * Owlready * Adding relation aputv5e.n4687e6 hasParentNode aputv5e.s4687e6
# * Owlready * Adding relation aputv5e.n4687e6 immediateParentNode aputv5e.s4687e6
# * Owlready * Adding relation aputv5e.n4687e6 hasChildNode aputv5e.nd96abc
# * Owlready * Adding relation aputv5e.n4687e6 hasChildNode aputv5e.n6c182f
# * Owlready * Adding relation aputv5e.n4687e6 hasChildNode aputv5e.nb47aca
# * Owlready * Adding relation aputv5e.n4687e6 hasChildNode aputv5e.n2ebac2
# * Owlready * Adding relation aputv5e.n4687e6 immediateChildNode aputv5e.n6c182f
# * Owlready * Adding relation aputv5e.n4687e6 immediateChildNode aputv5e.nb47aca
# * Owlready * Adding relation aputv5e.n5153bc hasParentNode aputv5e.s4687e6
# * Owlready * Adding relation aputv5e.n5153bc immediateParentNode aputv5e.s4687e6
# * Owlready * Adding relation aputv5e.n5153bc hasChildNode aputv5e.ne7efb9
# * Owlready * Adding relation aputv5e.n5153bc immediateChildNode aputv5e.ne7efb9
# * Owlready * Adding relation aputv5e.n733005 relatedPolicy aputv5e.p007
# * Owlready * Adding relation aputv5e.n733005 hasParentNode aputv5e.s4687e6
# * Owlready * Adding relation aputv5e.n733005 hasParentNode aputv5e.nb30975
# * Owlready * Adding relation aputv5e.n733005 immediateParentNode aputv5e.nb30975
# * Owlready * Adding relation aputv5e.n86341b hasParentNode aputv5e.s4687e6
# * Owlready * Adding relation aputv5e.n86341b hasParentNode aputv5e.n047a9b
# * Owlready * Adding relation aputv5e.n86341b immediateParentNode aputv5e.n047a9b
# * Owlready * Adding relation aputv5e.n6c182f hasParentNode aputv5e.s4687e6
# * Owlready * Adding relation aputv5e.n6c182f hasParentNode aputv5e.n4687e6
# * Owlready * Adding relation aputv5e.n6c182f immediateParentNode aputv5e.n4687e6
# * Owlready * Adding relation aputv5e.n6c182f hasChildNode aputv5e.nd96abc
# * Owlready * Adding relation aputv5e.n6c182f hasChildNode aputv5e.n2ebac2
# * Owlready * Adding relation aputv5e.nb30975 hasParentNode aputv5e.s4687e6
# * Owlready * Adding relation aputv5e.nb30975 immediateParentNode aputv5e.s4687e6
# * Owlready * Adding relation aputv5e.nb30975 hasChildNode aputv5e.n733005
# * Owlready * Adding relation aputv5e.nb30975 immediateChildNode aputv5e.n733005
# * Owlready * Adding relation aputv5e.nb47aca hasParentNode aputv5e.s4687e6
# * Owlready * Adding relation aputv5e.nb47aca hasParentNode aputv5e.n4687e6
# * Owlready * Adding relation aputv5e.nb47aca immediateParentNode aputv5e.n4687e6
# * Owlready * Adding relation aputv5e.n2ebac2 hasStatus apuf.Violated
# * Owlready * Adding relation aputv5e.n2ebac2 relatedPolicy aputv5e.p005
# * Owlready * Adding relation aputv5e.n2ebac2 inferredRule aputv5e.rcp
# * Owlready * Adding relation aputv5e.nf19373 hasStatus apuf.Violated
# * Owlready * Adding relation aputv5e.nf19373 relatedPolicy aputv5e.p005
# * Owlready * Adding relation aputv5e.nf19373 inferredRule aputv5e.rcp
# * Owlready * Adding relation aputv5e.ne7efb9 hasStatus apuf.Violated
# * Owlready * Adding relation aputv5e.ne7efb9 relatedPolicy aputv5e.p005
# * Owlready * Adding relation aputv5e.ne7efb9 inferredRule aputv5e.rcp
# * Owlready * Adding relation aputv5e.n733005 hasStatus apuf.RowTag
# * Owlready * Adding relation aputv5e.n733005 inferredRule aputv5e.rrp
# * Owlready * Adding relation aputv5e.n733005 inferredRule aputv5e.rrv
#     - Ontology saved to ../ontology_file/resolved_query_instances.rdf
# * Owlready2 * Pellet took 2.3199310302734375 seconds
# * Owlready * (NB: only changes on entities loaded in Python are shown, other changes are done but not listed)

# %%
status_set = instantiator.get_column_ref_instances() | instantiator.get_table_ref_instances()
print("Rule set: ", ", ".join(set([s.get("Rule") for s in status_set.values() if s.get("Rule") is not None])))
print("Policy set: ", ", ".join(set([s.get("Policy") for s in status_set.values() if s.get("Policy") is not None])))

pruner = ASTPruner(instantiator)
# 4. Prune the AST based on the ontology state
pruner.prune()
print(sql_op.to_sql())
# Out:
# Rule set:  rrp, rcp
# Policy set:  p005, p007
# --- Starting AST Pruning Process ---
# Query before pruning: SELECT l.duration, COUNT(l.loan_id) AS loan_count FROM "Client" AS c LEFT JOIN "Loan" AS l ON c.client_id = l.account_id GROUP BY c.client_id
# --> Stage 1: Pruning based on table statuses...
#      - TableRef 'n733005' is RowTag. Adding condition to parent statement.
#      - Found conditions: ["gender = 'male'"]
#      - Found target statement 'n4687e6'. Applying WHERE clause.
# --> Stage 2: Pruning based on column statuses...
#      - Initial violated column IDs: ['n2ebac2', 'nf19373', 'ne7efb9']
#  Alias node: COUNT(l.loan_id) AS loan_count
#     - Cascading removal of Function 'COUNT()' because its argument was removed.
#     - Cascading removal of Alias 'AS loan_count' because its expression was removed.
#      - Warning: Pruning reached max iterations. The AST may not be stable.
#      - Pruning complete (max iterations reached).
# SELECT
#   l.duration
# FROM "Client" AS c
# LEFT JOIN "Loan" AS l
# WHERE
#   gender = 'male'

# %% [markdown]
# ---

# %%
sql_op = SqlglotOperator(query)
# view the sqlglot AST
sql_op.ast
# Out:
# Select(
#   expressions=[
#     Star()],
#   from=From(
#     this=Table(
#       this=Identifier(this='Client', quoted=True))),
#   where=Where(
#     this=In(
#       this=Column(
#         this=Identifier(this=district_id, quoted=False)),
#       query=Subquery(
#         this=Select(
#           expressions=[
#             Column(
#               this=Identifier(this=district_id, quoted=False))],
#           from=From(
#             this=Table(
#               this=Identifier(this='District', quoted=True))),
#           where=Where(
#             this=EQ(
#               this=Column(
#                 this=Identifier(this=name, quoted=False)),
#               expression=Literal(this='Prague', is_string=True))))))))

# %%
tree_op = ASTTreeOperator(sql_op)
print("\nCustom AST Tree:")
tree_op.pretty_print()
# Out:
# Custom AST Tree:
# └── <(s766777) Statement |  (SelectStatement) [remove=False]>
#     ├── <(n766777) Clause |  (SelectClause) [remove=False]>
#     │   └── <(n4e0fa9) Expression |  (Wildcard) [remove=False]>
#     ├── <(n4f6d95) Clause |  (FromClause) [remove=False]>
#     │   └── <(ne82663) Expression |  (TableRef) [reftable=Client] [remove=False]>
#     └── <(n05b0db) Clause |  (WhereClause) [remove=False] [value=district_id IN (SELECT district_id FROM "District" WHERE name = 'Prague')]>
#         └── <(n8c63a0) Expression |  (Operator) [remove=False] [logics=False] [value=district_id]>
#             ├── <(nc75722) Expression |  (ColumnRef) [reftable=None, refcol=district_id] [remove=False]>
#             └── <(nff0888) Expression |  (Subquery) [remove=False]>
#                 ├── <(n05d903) Clause |  (SelectClause) [remove=False]>
#                 │   └── <(n38fa87) Expression |  (ColumnRef) [reftable=None, refcol=district_id] [remove=False]>
#                 ├── <(nb3eea1) Clause |  (FromClause) [remove=False]>
#                 │   └── <(ne70191) Expression |  (TableRef) [reftable=District] [remove=False]>
#                 └── <(nbc30d1) Clause |  (WhereClause) [remove=False] [value=name = 'Prague']>
#                     └── <(n029a2b) Expression |  (Operator) [remove=False] [logics=False] [value=name]>
#                         ├── <(n5185f5) Expression |  (ColumnRef) [reftable=None, refcol=name] [remove=False]>
#                         └── <(n399dce) Expression |  (Literal) [value=Prague] [remove=False] [value=Prague]>

# %%
onto_path = "../ontology_file/aputv5e.rdf"
output_path = "../ontology_file/resolved_query_instances.rdf"
agent_id = "a0012"

# 1. Create an instance of the class
instantiator = OntologyOperator(onto_path)

instantiator.instantiate_ontology(tree_op, agent_id)
tree_op.pretty_print()
# 3. Run the reasoner and save the ontology
instantiator.reason_and_save(output_path, save=True)
# Out:
# table entities: {'Card': 't007', 'Disposition': 't005', 'District': 't008', 'Order': 't001', 'Transaction': 't002', 'Account': 't003', 'Loan': 't004', 'Client': 't006', 'xxxxx': 't00x'}
# column lookup: {('xxxxx', 'ooooo'): 'c00x', ('Card', 'type'): 'c026', ('Order', 'order_id'): 'c001', ('Order', 'account_to'): 'c004', ('Order', 'k_symbol'): 'c006', ('Transaction', 'trans_id'): 'c007', ('Loan', 'loan_id'): 'c016', ('Card', 'disp_id'): 'c020', ('Disposition', 'disp_id'): 'c020', ('Disposition', 'client_id'): 'c021', ('Client', 'client_id'): 'c021', ('Card', 'card_id'): 'c025', ('Transaction', 'k_symbol'): 'c032', ('Disposition', 'account_id'): 'c002', ('Order', 'account_id'): 'c002', ('Transaction', 'account_id'): 'c002', ('Account', 'account_id'): 'c002', ('Loan', 'account_id'): 'c002', ('Client', 'account_id'): 'c002', ('Order', 'amount'): 'c005', ('Transaction', 'date'): 'c008', ('Transaction', 'type'): 'c009', ('District', 'district_id'): 'c014', ('Account', 'district_id'): 'c014', ('Client', 'district_id'): 'c014', ('Transaction', 'amount'): 'c031', ('Account', 'date'): 'c033', ('Loan', 'date'): 'c034', ('Loan', 'amount'): 'c035', ('Order', 'bank_to'): 'c003', ('Transaction', 'operation'): 'c010', ('Transaction', 'balance'): 'c011', ('Transaction', 'bank'): 'c012', ('Transaction', 'account'): 'c013', ('Account', 'frequency'): 'c015', ('Loan', 'duration'): 'c017', ('Loan', 'payments'): 'c018', ('Loan', 'status'): 'c019', ('Disposition', 'type'): 'c022', ('Client', 'gender'): 'c023', ('Client', 'birth_date'): 'c024', ('Card', 'issued'): 'c027', ('District', 'name'): 'c028'}
# --> Instantiating ontology individuals...
# SELECT account, COUNT(type) AS types FROM Transaction WHERE account_id IN (SELECT account_id FROM Account WHERE district_id = 'd002')
# Found 1 FROM/Join nodes in statement sd010ab.
# Initial in-context sources: {'Transaction': {'type': 'base_table', 'name': 'Transaction'}}
# Found 1 FROM/Join nodes in statement n4d46c8.
# Initial in-context sources: {'Account': {'type': 'base_table', 'name': 'Account'}}
# Resolving column 'account_id' in context of table alias 'None' | context_sources: {'Account': {'type': 'base_table', 'name': 'Account'}, 'Transaction': {'type': 'base_table', 'name': 'Transaction'}}
# Resolving column 'district_id' in context of table alias 'None' | context_sources: {'Account': {'type': 'base_table', 'name': 'Account'}, 'Transaction': {'type': 'base_table', 'name': 'Transaction'}}
# Resolving column 'account' in context of table alias 'None' | context_sources: {'Transaction': {'type': 'base_table', 'name': 'Transaction'}}
# Resolving column 'type' in context of table alias 'None' | context_sources: {'Transaction': {'type': 'base_table', 'name': 'Transaction'}}
# Resolving column 'account_id' in context of table alias 'None' | context_sources: {'Transaction': {'type': 'base_table', 'name': 'Transaction'}}
#     - Instantiated 2 TableRefs and 5 ColumnRefs.
# └── <(sd010ab) Statement |  (SelectStatement) [remove=False]>
#     ├── <(nd010ab) Clause |  (SelectClause) [remove=False]>
#     │   ├── <(n869d9e) Expression |  (ColumnRef) [reftable=Transaction, refcol=account] [table_reference_id=t002] [column_reference_id=c013] [remove=False]>
#     │   └── <(n4ea491) Expression |  (Alias) [alias=types] [remove=False]>
#     │       └── <(n55c4a4) Expression |  (Function) [remove=False]>
#     │           └── <(n62f13d) Expression |  (ColumnRef) [reftable=Transaction, refcol=type] [table_reference_id=t002] [column_reference_id=c009] [remove=False]>
#     ├── <(n7b4ba2) Clause |  (FromClause) [remove=False]>
#     │   └── <(nac583b) Expression |  (TableRef) [reftable=Transaction] [table_reference_id=t002] [remove=False]>
#     └── <(nb8d2f3) Clause |  (WhereClause) [remove=False] [value=account_id IN (SELECT account_id FROM Account WHERE district_id = 'd002')]>
#         └── <(nd78891) Expression |  (Operator) [remove=False] [logics=False] [value=account_id]>
#             ├── <(n25f16f) Expression |  (ColumnRef) [reftable=Transaction, refcol=account_id] [table_reference_id=t002] [column_reference_id=c002] [remove=False]>
#             └── <(n4d46c8) Expression |  (Subquery) [remove=False]>
#                 ├── <(nafe798) Clause |  (SelectClause) [remove=False]>
#                 │   └── <(nd44a29) Expression |  (ColumnRef) [reftable=Account, refcol=account_id] [table_reference_id=t003] [column_reference_id=c002] [remove=False]>
#                 ├── <(n4989b5) Clause |  (FromClause) [remove=False]>
#                 │   └── <(ndbceb6) Expression |  (TableRef) [reftable=Account] [table_reference_id=t003] [remove=False]>
#                 └── <(n9d8104) Clause |  (WhereClause) [remove=False] [value=district_id = 'd002']>
#                     └── <(nf3a682) Expression |  (Operator) [remove=False] [logics=False] [value=district_id]>
#                         ├── <(n371109) Expression |  (ColumnRef) [reftable=Account, refcol=district_id] [table_reference_id=t003] [column_reference_id=c014] [remove=False]>
#                         └── <(n4378bb) Expression |  (Literal) [value=d002] [remove=False] [value=d002]>
# --> Running reasoner and saving ontology...
# * Owlready2 * Running Pellet...
#     java -Xmx2000M -cp c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\antlr-3.2.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\antlr-runtime-3.2.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\aterm-java-1.6.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\commons-codec-1.6.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\httpclient-4.2.3.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\httpcore-4.2.2.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\jcl-over-slf4j-1.6.4.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\jena-arq-2.10.0.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\jena-core-2.10.0.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\jena-iri-0.9.5.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\jena-tdb-0.10.0.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\jgrapht-jdk1.5.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\log4j-1.2-api-2.19.0.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\log4j-api-2.19.0.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\log4j-core-2.19.0.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\owlapi-distribution-3.4.3-bin.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\pellet-2.3.1.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\slf4j-api-1.6.4.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\slf4j-log4j12-1.6.4.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\xercesImpl-2.10.0.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\xml-apis-1.4.01.jar pellet.Pellet realize --loader Jena --input-format N-Triples --infer-prop-values --ignore-imports C:\Users\NIPUN_~1\AppData\Local\Temp\tmpoglrtv7v
# * Owlready2 * Pellet took 2.152822256088257 seconds
# * Owlready * (NB: only changes on entities loaded in Python are shown, other changes are done but not listed)
# * Owlready2 * Running Pellet...
#     java -Xmx2000M -cp c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\antlr-3.2.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\antlr-runtime-3.2.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\aterm-java-1.6.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\commons-codec-1.6.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\httpclient-4.2.3.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\httpcore-4.2.2.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\jcl-over-slf4j-1.6.4.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\jena-arq-2.10.0.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\jena-core-2.10.0.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\jena-iri-0.9.5.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\jena-tdb-0.10.0.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\jgrapht-jdk1.5.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\log4j-1.2-api-2.19.0.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\log4j-api-2.19.0.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\log4j-core-2.19.0.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\owlapi-distribution-3.4.3-bin.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\pellet-2.3.1.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\slf4j-api-1.6.4.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\slf4j-log4j12-1.6.4.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\xercesImpl-2.10.0.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\xml-apis-1.4.01.jar pellet.Pellet realize --loader Jena --input-format N-Triples --infer-prop-values --ignore-imports C:\Users\NIPUN_~1\AppData\Local\Temp\tmpewbxcjvz
# * Owlready * Adding relation aputv5e.ndbceb6 hasParentNode aputv5e.nb8d2f3
# * Owlready * Adding relation aputv5e.ndbceb6 hasParentNode aputv5e.n4d46c8
# * Owlready * Adding relation aputv5e.ndbceb6 hasParentNode aputv5e.nd78891
# * Owlready * Adding relation aputv5e.ndbceb6 hasParentNode aputv5e.n4989b5
# * Owlready * Adding relation aputv5e.ndbceb6 hasParentNode aputv5e.sd010ab
# * Owlready * Adding relation aputv5e.ndbceb6 immediateParentNode aputv5e.n4989b5
# * Owlready * Adding relation aputv5e.n7b4ba2 hasParentNode aputv5e.sd010ab
# * Owlready * Adding relation aputv5e.n7b4ba2 immediateParentNode aputv5e.sd010ab
# * Owlready * Adding relation aputv5e.n7b4ba2 hasChildNode aputv5e.nac583b
# * Owlready * Adding relation aputv5e.n7b4ba2 immediateChildNode aputv5e.nac583b
# * Owlready * Adding relation aputv5e.n4d46c8 hasParentNode aputv5e.nb8d2f3
# * Owlready * Adding relation aputv5e.n4d46c8 hasParentNode aputv5e.nd78891
# * Owlready * Adding relation aputv5e.n4d46c8 hasParentNode aputv5e.sd010ab
# * Owlready * Adding relation aputv5e.n4d46c8 hasChildNode aputv5e.ndbceb6
# * Owlready * Adding relation aputv5e.n4d46c8 hasChildNode aputv5e.n4378bb
# * Owlready * Adding relation aputv5e.n4d46c8 hasChildNode aputv5e.nf3a682
# * Owlready * Adding relation aputv5e.n4d46c8 hasChildNode aputv5e.nafe798
# * Owlready * Adding relation aputv5e.n4d46c8 hasChildNode aputv5e.n4989b5
# * Owlready * Adding relation aputv5e.n4d46c8 hasChildNode aputv5e.n9d8104
# * Owlready * Adding relation aputv5e.n4d46c8 hasChildNode aputv5e.n371109
# * Owlready * Adding relation aputv5e.n4d46c8 hasChildNode aputv5e.nd44a29
# * Owlready * Adding relation aputv5e.nd78891 hasParentNode aputv5e.nb8d2f3
# * Owlready * Adding relation aputv5e.nd78891 hasParentNode aputv5e.sd010ab
# * Owlready * Adding relation aputv5e.nd78891 immediateParentNode aputv5e.nb8d2f3
# * Owlready * Adding relation aputv5e.nd78891 hasChildNode aputv5e.ndbceb6
# * Owlready * Adding relation aputv5e.nd78891 hasChildNode aputv5e.n4378bb
# * Owlready * Adding relation aputv5e.nd78891 hasChildNode aputv5e.n25f16f
# * Owlready * Adding relation aputv5e.nd78891 hasChildNode aputv5e.nf3a682
# * Owlready * Adding relation aputv5e.nd78891 hasChildNode aputv5e.n4d46c8
# * Owlready * Adding relation aputv5e.nd78891 hasChildNode aputv5e.nafe798
# * Owlready * Adding relation aputv5e.nd78891 hasChildNode aputv5e.n4989b5
# * Owlready * Adding relation aputv5e.nd78891 hasChildNode aputv5e.n9d8104
# * Owlready * Adding relation aputv5e.nd78891 hasChildNode aputv5e.n371109
# * Owlready * Adding relation aputv5e.nd78891 hasChildNode aputv5e.nd44a29
# * Owlready * Adding relation aputv5e.nd010ab hasParentNode aputv5e.sd010ab
# * Owlready * Adding relation aputv5e.nd010ab immediateParentNode aputv5e.sd010ab
# * Owlready * Adding relation aputv5e.nd010ab hasChildNode aputv5e.n55c4a4
# * Owlready * Adding relation aputv5e.nd010ab hasChildNode aputv5e.n62f13d
# * Owlready * Adding relation aputv5e.nd010ab hasChildNode aputv5e.n4ea491
# * Owlready * Adding relation aputv5e.nd010ab hasChildNode aputv5e.n869d9e
# * Owlready * Adding relation aputv5e.nd010ab immediateChildNode aputv5e.n4ea491
# * Owlready * Adding relation aputv5e.nd010ab immediateChildNode aputv5e.n869d9e
# * Owlready * Adding relation aputv5e.sd010ab hasChildNode aputv5e.ndbceb6
# * Owlready * Adding relation aputv5e.sd010ab hasChildNode aputv5e.n25f16f
# * Owlready * Adding relation aputv5e.sd010ab hasChildNode aputv5e.nf3a682
# * Owlready * Adding relation aputv5e.sd010ab hasChildNode aputv5e.nd78891
# * Owlready * Adding relation aputv5e.sd010ab hasChildNode aputv5e.n4d46c8
# * Owlready * Adding relation aputv5e.sd010ab hasChildNode aputv5e.n4989b5
# * Owlready * Adding relation aputv5e.sd010ab hasChildNode aputv5e.n9d8104
# * Owlready * Adding relation aputv5e.sd010ab hasChildNode aputv5e.n371109
# * Owlready * Adding relation aputv5e.sd010ab hasChildNode aputv5e.nd010ab
# * Owlready * Adding relation aputv5e.sd010ab hasChildNode aputv5e.n55c4a4
# * Owlready * Adding relation aputv5e.sd010ab hasChildNode aputv5e.n4378bb
# * Owlready * Adding relation aputv5e.sd010ab hasChildNode aputv5e.n62f13d
# * Owlready * Adding relation aputv5e.sd010ab hasChildNode aputv5e.nac583b
# * Owlready * Adding relation aputv5e.sd010ab hasChildNode aputv5e.nb8d2f3
# * Owlready * Adding relation aputv5e.sd010ab hasChildNode aputv5e.n4ea491
# * Owlready * Adding relation aputv5e.sd010ab hasChildNode aputv5e.nafe798
# * Owlready * Adding relation aputv5e.sd010ab hasChildNode aputv5e.n869d9e
# * Owlready * Adding relation aputv5e.sd010ab hasChildNode aputv5e.nd44a29
# * Owlready * Adding relation aputv5e.sd010ab hasChildNode aputv5e.n7b4ba2
# * Owlready * Adding relation aputv5e.sd010ab immediateChildNode aputv5e.nb8d2f3
# * Owlready * Adding relation aputv5e.sd010ab immediateChildNode aputv5e.n7b4ba2
# * Owlready * Adding relation aputv5e.sd010ab immediateChildNode aputv5e.nd010ab
# * Owlready * Adding relation aputv5e.n25f16f hasParentNode aputv5e.nb8d2f3
# * Owlready * Adding relation aputv5e.n25f16f hasParentNode aputv5e.nd78891
# * Owlready * Adding relation aputv5e.n25f16f hasParentNode aputv5e.sd010ab
# * Owlready * Adding relation aputv5e.n4378bb hasParentNode aputv5e.nb8d2f3
# * Owlready * Adding relation aputv5e.n4378bb hasParentNode aputv5e.nf3a682
# * Owlready * Adding relation aputv5e.n4378bb hasParentNode aputv5e.n4d46c8
# * Owlready * Adding relation aputv5e.n4378bb hasParentNode aputv5e.nd78891
# * Owlready * Adding relation aputv5e.n4378bb hasParentNode aputv5e.n9d8104
# * Owlready * Adding relation aputv5e.n4378bb hasParentNode aputv5e.sd010ab
# * Owlready * Adding relation aputv5e.nf3a682 hasParentNode aputv5e.nb8d2f3
# * Owlready * Adding relation aputv5e.nf3a682 hasParentNode aputv5e.n4d46c8
# * Owlready * Adding relation aputv5e.nf3a682 hasParentNode aputv5e.nd78891
# * Owlready * Adding relation aputv5e.nf3a682 hasParentNode aputv5e.n9d8104
# * Owlready * Adding relation aputv5e.nf3a682 hasParentNode aputv5e.sd010ab
# * Owlready * Adding relation aputv5e.nf3a682 immediateParentNode aputv5e.n9d8104
# * Owlready * Adding relation aputv5e.nf3a682 hasChildNode aputv5e.n4378bb
# * Owlready * Adding relation aputv5e.nf3a682 hasChildNode aputv5e.n371109
# * Owlready * Adding relation aputv5e.nafe798 hasParentNode aputv5e.nb8d2f3
# * Owlready * Adding relation aputv5e.nafe798 hasParentNode aputv5e.n4d46c8
# * Owlready * Adding relation aputv5e.nafe798 hasParentNode aputv5e.nd78891
# * Owlready * Adding relation aputv5e.nafe798 hasParentNode aputv5e.sd010ab
# * Owlready * Adding relation aputv5e.nafe798 hasChildNode aputv5e.nd44a29
# * Owlready * Adding relation aputv5e.nafe798 immediateChildNode aputv5e.nd44a29
# * Owlready * Adding relation aputv5e.n371109 hasParentNode aputv5e.nb8d2f3
# * Owlready * Adding relation aputv5e.n371109 hasParentNode aputv5e.nf3a682
# * Owlready * Adding relation aputv5e.n371109 hasParentNode aputv5e.n4d46c8
# * Owlready * Adding relation aputv5e.n371109 hasParentNode aputv5e.nd78891
# * Owlready * Adding relation aputv5e.n371109 hasParentNode aputv5e.n9d8104
# * Owlready * Adding relation aputv5e.n371109 hasParentNode aputv5e.sd010ab
# * Owlready * Adding relation aputv5e.nac583b hasParentNode aputv5e.sd010ab
# * Owlready * Adding relation aputv5e.nac583b hasParentNode aputv5e.n7b4ba2
# * Owlready * Adding relation aputv5e.nac583b immediateParentNode aputv5e.n7b4ba2
# * Owlready * Adding relation aputv5e.nb8d2f3 hasParentNode aputv5e.sd010ab
# * Owlready * Adding relation aputv5e.nb8d2f3 immediateParentNode aputv5e.sd010ab
# * Owlready * Adding relation aputv5e.nb8d2f3 hasChildNode aputv5e.ndbceb6
# * Owlready * Adding relation aputv5e.nb8d2f3 hasChildNode aputv5e.n4378bb
# * Owlready * Adding relation aputv5e.nb8d2f3 hasChildNode aputv5e.n25f16f
# * Owlready * Adding relation aputv5e.nb8d2f3 hasChildNode aputv5e.nf3a682
# * Owlready * Adding relation aputv5e.nb8d2f3 hasChildNode aputv5e.nd78891
# * Owlready * Adding relation aputv5e.nb8d2f3 hasChildNode aputv5e.n4d46c8
# * Owlready * Adding relation aputv5e.nb8d2f3 hasChildNode aputv5e.nafe798
# * Owlready * Adding relation aputv5e.nb8d2f3 hasChildNode aputv5e.n4989b5
# * Owlready * Adding relation aputv5e.nb8d2f3 hasChildNode aputv5e.n9d8104
# * Owlready * Adding relation aputv5e.nb8d2f3 hasChildNode aputv5e.n371109
# * Owlready * Adding relation aputv5e.nb8d2f3 hasChildNode aputv5e.nd44a29
# * Owlready * Adding relation aputv5e.nb8d2f3 immediateChildNode aputv5e.nd78891
# * Owlready * Adding relation aputv5e.n9d8104 hasParentNode aputv5e.nb8d2f3
# * Owlready * Adding relation aputv5e.n9d8104 hasParentNode aputv5e.n4d46c8
# * Owlready * Adding relation aputv5e.n9d8104 hasParentNode aputv5e.nd78891
# * Owlready * Adding relation aputv5e.n9d8104 hasParentNode aputv5e.sd010ab
# * Owlready * Adding relation aputv5e.n9d8104 hasChildNode aputv5e.n4378bb
# * Owlready * Adding relation aputv5e.n9d8104 hasChildNode aputv5e.nf3a682
# * Owlready * Adding relation aputv5e.n9d8104 hasChildNode aputv5e.n371109
# * Owlready * Adding relation aputv5e.n9d8104 immediateChildNode aputv5e.nf3a682
# * Owlready * Adding relation aputv5e.n4ea491 hasParentNode aputv5e.sd010ab
# * Owlready * Adding relation aputv5e.n4ea491 hasParentNode aputv5e.nd010ab
# * Owlready * Adding relation aputv5e.n4ea491 immediateParentNode aputv5e.nd010ab
# * Owlready * Adding relation aputv5e.n4ea491 hasChildNode aputv5e.n55c4a4
# * Owlready * Adding relation aputv5e.n4ea491 hasChildNode aputv5e.n62f13d
# * Owlready * Adding relation aputv5e.n869d9e hasParentNode aputv5e.sd010ab
# * Owlready * Adding relation aputv5e.n869d9e hasParentNode aputv5e.nd010ab
# * Owlready * Adding relation aputv5e.n869d9e immediateParentNode aputv5e.nd010ab
# * Owlready * Adding relation aputv5e.nd44a29 hasParentNode aputv5e.nb8d2f3
# * Owlready * Adding relation aputv5e.nd44a29 hasParentNode aputv5e.nafe798
# * Owlready * Adding relation aputv5e.nd44a29 hasParentNode aputv5e.n4d46c8
# * Owlready * Adding relation aputv5e.nd44a29 hasParentNode aputv5e.nd78891
# * Owlready * Adding relation aputv5e.nd44a29 hasParentNode aputv5e.sd010ab
# * Owlready * Adding relation aputv5e.nd44a29 immediateParentNode aputv5e.nafe798
# * Owlready * Adding relation aputv5e.n4989b5 hasParentNode aputv5e.nb8d2f3
# * Owlready * Adding relation aputv5e.n4989b5 hasParentNode aputv5e.n4d46c8
# * Owlready * Adding relation aputv5e.n4989b5 hasParentNode aputv5e.nd78891
# * Owlready * Adding relation aputv5e.n4989b5 hasParentNode aputv5e.sd010ab
# * Owlready * Adding relation aputv5e.n4989b5 hasChildNode aputv5e.ndbceb6
# * Owlready * Adding relation aputv5e.n4989b5 immediateChildNode aputv5e.ndbceb6
# * Owlready * Adding relation aputv5e.n55c4a4 hasParentNode aputv5e.n4ea491
# * Owlready * Adding relation aputv5e.n55c4a4 hasParentNode aputv5e.sd010ab
# * Owlready * Adding relation aputv5e.n55c4a4 hasParentNode aputv5e.nd010ab
# * Owlready * Adding relation aputv5e.n55c4a4 hasChildNode aputv5e.n62f13d
# * Owlready * Adding relation aputv5e.n62f13d hasParentNode aputv5e.n55c4a4
# * Owlready * Adding relation aputv5e.n62f13d hasParentNode aputv5e.n4ea491
# * Owlready * Adding relation aputv5e.n62f13d hasParentNode aputv5e.sd010ab
# * Owlready * Adding relation aputv5e.n62f13d hasParentNode aputv5e.nd010ab
#     - Ontology saved to ../ontology_file/resolved_query_instances.rdf
# * Owlready2 * Pellet took 2.2287039756774902 seconds
# * Owlready * (NB: only changes on entities loaded in Python are shown, other changes are done but not listed)

# %%
print("Column reference node status: ", instantiator.get_column_ref_instances())
print("Table reference node status: ", instantiator.get_table_ref_instances())
# Out:
# Column reference node status:  {'n869d9e': {'Status': 'Aligned'}, 'n62f13d': {'Status': 'Aligned'}, 'n25f16f': {'Status': 'Aligned'}, 'nd44a29': {'Status': 'Aligned'}, 'n371109': {'Status': 'Aligned'}}
# Table reference node status:  {'nac583b': {'Status': 'Aligned'}, 'ndbceb6': {'Status': 'Aligned'}}

# %%
pruner = ASTPruner(instantiator)

# # 4. Prune the AST based on the ontology state
pruner.prune()

print(sql_op.to_sql())
# Out:
# --- Starting AST Pruning Process ---
# Query before pruning: SELECT account, COUNT(type) AS types FROM Transaction WHERE account_id IN (SELECT account_id FROM Account WHERE district_id = 'd002')
# --> Stage 1: Pruning based on table statuses...
# --> Stage 2: Pruning based on column statuses...
#      - Initial violated column IDs: []
#      - No violated columns found.
# SELECT
#   account,
#   COUNT(type) AS types
# FROM Transaction
# WHERE

# %%
instantiator.cleanup()
# Out:
# --> Cleanup: Attempting to delete 21 instances...
#     - Deleted instance: aputv5e.se26777
#     - Deleted instance: aputv5e.ne26777
#     - Deleted instance: aputv5e.n0dad3d
#     - Deleted instance: aputv5e.n902237
#     - Deleted instance: aputv5e.n8899cc
#     - Deleted instance: aputv5e.n0e5d89
#     - Deleted instance: aputv5e.n088fdd
#     - Deleted instance: aputv5e.n790936
#     - Deleted instance: aputv5e.nf97449
#     - Deleted instance: aputv5e.nb459e5
#     - Deleted instance: aputv5e.n25d83d
#     - Deleted instance: aputv5e.nf277d3
#     - Deleted instance: aputv5e.n7957d9
#     - Deleted instance: aputv5e.ncf3355
#     - Deleted instance: aputv5e.ne85a0d
#     - Deleted instance: aputv5e.nb2778d
#     - Deleted instance: aputv5e.nc3a72e
#     - Deleted instance: aputv5e.n53a103
#     - Deleted instance: aputv5e.ncb44e0
#     - Deleted instance: aputv5e.nca1171
#     - Deleted instance: aputv5e.n91e15b
# --> Cleanup complete. Successfully deleted 21 instances.

# %%
import sqlglot
from sqlglot import exp
from sqlglot.expressions import Expression

def sub_condition_exists(full_condition: str, sub_condition: str) -> bool:
    """
    Checks if a sub-condition is structurally present in a full condition
    by parsing both into an Abstract Syntax Tree (AST).

    Args:
        full_condition (str): The complete WHERE clause string.
        sub_condition (str): The sub-condition string to search for.

    Returns:
        True if a structurally identical sub-condition is found, False otherwise.
    """
    try:
        # Parse both conditions into their respective ASTs
        full_ast: Expression = sqlglot.parse_one(full_condition, read="where").this
        sub_ast: Expression = sqlglot.parse_one(sub_condition, read="where").this
    except Exception:
        # If either string is invalid SQL, they cannot match.
        return False

    # Walk the full AST and check if any node is structurally equal
    # to the sub-condition's AST. sqlglot's `==` operator on expressions
    # performs this structural comparison, ignoring whitespace and formatting.
    for node in full_ast.walk():
        if node == sub_ast:
            return True
            
    return False

# --- Example Usage ---
full_clause = "c.status = 'active' AND (l.amount > 5000 OR l.duration = 60)"
sub_clause_to_find = "l.amount>5000"

print(f"Does the sub-condition exist? -> {sub_condition_exists(full_clause, sub_clause_to_find)}")
# Expected Output: Does the sub-condition exist? -> True
# Out:
# Does the sub-condition exist? -> False

# %%
import re

def normalize_condition(condition: str) -> str:
    """
    Cleans up a single SQL condition string to make it comparable.
    - Converts to lowercase
    - Removes extra whitespace
    - Removes whitespace around operators
    """
    # Convert to lowercase and strip leading/trailing whitespace
    norm = condition.strip().lower()
    # Replace multiple spaces with a single space
    norm = re.sub(r'\s+', ' ', norm)
    # Remove whitespace around operators like =, >, <, etc.
    norm = re.sub(r'\s*([=<>!]+)\s*', r'\1', norm)
    return norm

def sub_condition_exists_no_parser(full_condition: str, sub_condition: str) -> bool:
    """
    Checks if a sub-condition exists in a full condition without parsing SQL.

    LIMITATIONS:
    - Only works reliably for conditions joined by AND.
    - Does not understand OR logic or complex nested parentheses.
    - Does not understand SQL semantics (e.g., BETWEEN).
    """
    if not sub_condition:
        return True
    if not full_condition:
        return False

    try:
        # Split the full condition by 'AND' (case-insensitive) and normalize each part
        full_parts = {
            normalize_condition(part)
            for part in re.split(r'\s+AND\s+', full_condition, flags=re.IGNORECASE)
        }

        # Split the sub-condition by 'AND' and normalize each part
        sub_parts = {
            normalize_condition(part)
            for part in re.split(r'\s+AND\s+', sub_condition, flags=re.IGNORECASE)
        }

        # Check if the set of sub-condition parts is a subset of the full condition parts
        return sub_parts.issubset(full_parts)
    except Exception:
        # If any regex or other error occurs, assume failure
        return False

# --- Example Usage ---
full_clause = "c.status = 'active' AND c.age > 30 AND c.gender = 'F'"

# Test 1: Simple case (should be True)
sub1 = "c.age > 30"
print(f"'{sub1}' exists? -> {sub_condition_exists_no_parser(full_clause, sub1)}")

# Test 2: Different order and whitespace (should be True)
sub2 = "c.gender='F'  AND  c.status = 'active'"
print(f"'{sub2}' exists? -> {sub_condition_exists_no_parser(full_clause, sub2)}")

# Test 3: Non-existent condition (should be False)
sub3 = "c.age < 20"
print(f"'{sub3}' exists? -> {sub_condition_exists_no_parser(full_clause, sub3)}")

# Test 4: A case where this method FAILS (involving OR)
full_clause_with_or = "c.status = 'active' OR c.age > 30"
sub4 = "c.age > 30"
print(f"\n--- LIMITATION EXAMPLE ---")
print(f"'{sub4}' in '{full_clause_with_or}'? -> {sub_condition_exists_no_parser(full_clause_with_or, sub4)}")
# This will incorrectly return False because the logic doesn't understand OR.
# Out:
# 'c.age > 30' exists? -> True
# 'c.gender='F'  AND  c.status = 'active'' exists? -> True
# 'c.age < 20' exists? -> False
#
# --- LIMITATION EXAMPLE ---
# 'c.age > 30' in 'c.status = 'active' OR c.age > 30'? -> False

# %%
from sqlglot import exp

# 1. Manually build the column and subquery nodes (this part is correct)
col_node = exp.Column(this=exp.Identifier(this='district_id', quoted=False))

subquery_node = exp.Subquery(
    this=exp.Select(
        expressions=[
            exp.Column(this=exp.Identifier(this='district_id', quoted=False))
        ],
        from_=exp.From(
            this=exp.Table(this=exp.Identifier(this='District', quoted=True))
        ),
        where=exp.Where(
            this=exp.EQ(
                this=exp.Column(this=exp.Identifier(this='name', quoted=False)),
                expression=exp.Literal(this='Prague', is_string=True)
            )
        )
    )
)

# 2. THE CORRECT WAY TO CREATE THE 'In' NODE:
#    Pass the subquery in a list to the 'expressions' argument.
print("--- Creating the In node correctly using expressions=[...] ---")
in_node = exp.In(this=col_node, expressions=[subquery_node])


# 3. NOW, ACCESSING '.expressions' WILL WORK AS INTENDED:
print(f"\nThe .expressions attribute now contains: {in_node.expressions}")

# The subquery is the first (and only) item in the list.
the_query_section = in_node.expressions[0]

print(f"\nType of the query section: {type(the_query_section)}")
print(f"SQL of the query section: {the_query_section.sql()}")
# Out:
# --- Creating the In node correctly using expressions=[...] ---
#
# The .expressions attribute now contains: [Subquery(
#   this=Select(
#     expressions=[
#       Column(
#         this=Identifier(this=district_id, quoted=False))],
#     from_=From(
#       this=Table(
#         this=Identifier(this='District', quoted=True))),
#     where=Where(
#       this=EQ(
#         this=Column(
#           this=Identifier(this=name, quoted=False)),
#         expression=Literal(this='Prague', is_string=True)))))]
#
# Type of the query section: <class 'sqlglot.expressions.Subquery'>
# SQL of the query section: (SELECT district_id WHERE name = 'Prague')

# %%
import sqlglot
from sqlglot import exp

# The SQL query as a text string
sql_string = """
SELECT *
FROM "Client"
WHERE district_id IN (
    SELECT district_id
    FROM "District"
    WHERE name = 'Prague'
)
"""

print(f"--- Using sqlglot version: {sqlglot.__version__} ---")

# Let sqlglot parse the string into an AST
try:
    parsed_ast = sqlglot.parse_one(sql_string)
    in_node = parsed_ast.find(exp.In)

    if not in_node:
        print("\nERROR: Could not find an 'In' node in the parsed query.")
    else:
        print("\n--- Full Inspection of the Parsed 'In' Node ---")

        # Use vars() to get the instance dictionary, which shows stored arguments.
        # This is the most important part for debugging.
        print("\n1. Inspecting `vars(in_node)`:")
        try:
            print(vars(in_node))
        except TypeError:
            print("`vars()` not applicable for this object.")

        # Let's try to access some likely candidates if they exist
        print("\n2. Checking potential attributes:")
        potential_attributes = ['this', 'expressions', 'query', 'unnest', 'kind', 'subquery']
        for attr_name in potential_attributes:
            if hasattr(in_node, attr_name):
                value = getattr(in_node, attr_name)
                # To keep the output clean, we'll just show the type for complex objects
                value_repr = type(value) if isinstance(value, exp.Expression) else value
                print(f"  - Attribute '{attr_name}' exists. Value/Type: {value_repr}")
            else:
                print(f"  - Attribute '{attr_name}' does NOT exist.")

except Exception as e:
    print(f"\nAn error occurred during parsing or inspection: {e}")
# Out:
# --- Using sqlglot version: 27.6.0 ---
#
# --- Full Inspection of the Parsed 'In' Node ---
#
# 1. Inspecting `vars(in_node)`:
# {}
#
# 2. Checking potential attributes:
#   - Attribute 'this' exists. Value/Type: <class 'sqlglot.expressions.Column'>
#   - Attribute 'expressions' exists. Value/Type: []
#   - Attribute 'query' does NOT exist.
#   - Attribute 'unnest' exists. Value/Type: <bound method Expression.unnest of In(
#   this=Column(
#     this=Identifier(this=district_id, quoted=False)),
#   query=Subquery(
#     this=Select(
#       expressions=[
#         Column(
#           this=Identifier(this=district_id, quoted=False))],
#       from=From(
#         this=Table(
#           this=Identifier(this='District', quoted=True))),
#       where=Where(
#         this=EQ(
#           this=Column(
#             this=Identifier(this=name, quoted=False)),
#           expression=Literal(this='Prague', is_string=True))))))>
#   - Attribute 'kind' does NOT exist.
#   - Attribute 'subquery' does NOT exist.
