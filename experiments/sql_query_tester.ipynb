# %%
from copy import deepcopy

# %%
import sys 

sys.path.append("../")

# %%
from src import ASTPruner, ASTTreeOperator, SqlglotOperator, OntologyOperator, TreeNode

# %%
query = """SELECT l.loan_id, l.status FROM Loan l WHERE l.account_id IN (SELECT account_id FROM Account WHERE district_id = 'd002');"""

# %%
# query = "WITH AccountTransactions AS (SELECT a.account_id, a.frequency, t.type FROM Account a JOIN Transaction t ON a.account_id = t.account_id) SELECT * FROM AccountTransactions WHERE type = 'withdrawal';"

# %%
# query = """
# SELECT
#     c.duration,
#     c.date,
#     (
#         SELECT COUNT(*)
#         FROM Order o
#         WHERE o.account_id = c.account_id
#     ) AS total_orders,
#     (
#         SELECT AVG(o2.amount)
#         FROM Order o2
#         WHERE o2.account_id = c.account_id
#           AND o2.amount > 100
#     ) AS avg_recent_order_amount
# FROM Loan c
# WHERE c.status = 'active';
# """

# %%
# query = """INSERT INTO "Loan" (loan_id, account_id, amount) VALUES ('l123', 'a456', 5000);"""

# %%
onto_path = "../ontology_file/aputv5e.rdf"
output_path = "../ontology_file/resolved_query_instances.rdf"
agent_id = "a0012"

# 1. Create an instance of the class
instantiator = OntologyOperator(onto_path)
# Out:
# table entities: {'Card': 't007', 'Disposition': 't005', 'District': 't008', 'Order': 't001', 'Transaction': 't002', 'Account': 't003', 'Loan': 't004', 'Client': 't006'}
# column lookup: {('Card', 'type'): 'c026', ('Order', 'order_id'): 'c001', ('Order', 'account_to'): 'c004', ('Order', 'k_symbol'): 'c006', ('Transaction', 'trans_id'): 'c007', ('Loan', 'loan_id'): 'c016', ('Card', 'disp_id'): 'c020', ('Disposition', 'disp_id'): 'c020', ('Disposition', 'client_id'): 'c021', ('Client', 'client_id'): 'c021', ('Card', 'card_id'): 'c025', ('Transaction', 'k_symbol'): 'c032', ('Disposition', 'account_id'): 'c002', ('Order', 'account_id'): 'c002', ('Transaction', 'account_id'): 'c002', ('Account', 'account_id'): 'c002', ('Loan', 'account_id'): 'c002', ('Client', 'account_id'): 'c002', ('Order', 'amount'): 'c005', ('Transaction', 'date'): 'c008', ('Transaction', 'type'): 'c009', ('District', 'district_id'): 'c014', ('Account', 'district_id'): 'c014', ('Client', 'district_id'): 'c014', ('Account', 'frequency'): 'c015', ('Transaction', 'amount'): 'c031', ('Account', 'date'): 'c033', ('Loan', 'date'): 'c034', ('Loan', 'amount'): 'c035', ('Order', 'bank_to'): 'c003', ('Transaction', 'operation'): 'c010', ('Transaction', 'balance'): 'c011', ('Transaction', 'bank'): 'c012', ('Transaction', 'account'): 'c013', ('Loan', 'duration'): 'c017', ('Loan', 'payments'): 'c018', ('Loan', 'status'): 'c019', ('Disposition', 'type'): 'c022', ('Client', 'gender'): 'c023', ('Client', 'birth_date'): 'c024', ('Card', 'issued'): 'c027', ('District', 'name'): 'c028'}

# %%
query = """
WITH ClientAccounts AS (SELECT c.client_id, a.account_id FROM "Client" c JOIN "Disposition" d ON c.client_id = d.client_id JOIN "Account" a ON d.account_id = a.account_id) SELECT * FROM ClientAccounts;
 """

# %%
query = """
SELECT (SELECT MAX(l.amount) FROM "Loan" l) as max_loan FROM "Client" c;
"""

sql_op = SqlglotOperator(query)
tree_op = ASTTreeOperator(sql_op)
instantiator.instantiate_ontology(tree_op, agent_id)
tree_op.pretty_print()
# 3. Run the reasoner and save the ontology
instantiator.reason_and_save(output_path, save=True)
# Out:
# --> Instantiating ontology individuals...
# SELECT (SELECT MAX(l.amount) FROM "Loan" AS l) AS max_loan FROM "Client" AS c
#  context_sources after WITH clauses: subquery_context : {} | in_context_sources: {}
# Initial in-context sources: {'Client': {'type': 'base_table', 'name': 'Client'}, 'c': {'type': 'base_table', 'name': 'Client'}}
#  context_sources after WITH clauses: subquery_context : {} | in_context_sources: {}
# Initial in-context sources: {'Loan': {'type': 'base_table', 'name': 'Loan'}, 'l': {'type': 'base_table', 'name': 'Loan'}}
#  full context : {'Loan': {'type': 'base_table', 'name': 'Loan'}, 'l': {'type': 'base_table', 'name': 'Loan'}, 'Client': {'type': 'base_table', 'name': 'Client'}, 'c': {'type': 'base_table', 'name': 'Client'}}
# Resolving column 'amount' in context of table alias 'l' | context_sources: {'Loan': {'type': 'base_table', 'name': 'Loan'}, 'l': {'type': 'base_table', 'name': 'Loan'}, 'Client': {'type': 'base_table', 'name': 'Client'}, 'c': {'type': 'base_table', 'name': 'Client'}}
# Resolving table '<(nfa9bc5) Expression |  (TableRef) [reftable=Loan] [remove=False] [refalias=l]>' | context_sources: {'Loan': {'type': 'base_table', 'name': 'Loan'}, 'l': {'type': 'base_table', 'name': 'Loan'}, 'Client': {'type': 'base_table', 'name': 'Client'}, 'c': {'type': 'base_table', 'name': 'Client'}}
#  full context : {'Client': {'type': 'base_table', 'name': 'Client'}, 'c': {'type': 'base_table', 'name': 'Client'}}
# Resolving table '<(ndd3395) Expression |  (TableRef) [reftable=Client] [remove=False] [refalias=c]>' | context_sources: {'Client': {'type': 'base_table', 'name': 'Client'}, 'c': {'type': 'base_table', 'name': 'Client'}}
#     - Instantiated 2 TableRefs and 1 ColumnRefs.
# └── <(s0ced5f) Statement |  (SelectStatement) [remove=False]>
#     ├── <(n0ced5f) Clause |  (SelectClause) [remove=False]>
#     │   └── <(n96774d) Expression |  (Alias) [alias=max_loan] [remove=False]>
#     │       └── <(ncc9f27) Expression |  (Subquery) [remove=False]>
#     │           ├── <(n69eb16) Clause |  (SelectClause) [remove=False]>
#     │           │   └── <(n1fe705) Expression |  (Function) [remove=False]>
#     │           │       └── <(n4dfe75) Expression |  (ColumnRef) [reftable=Loan, refcol=amount] [table_reference_id=t004] [column_reference_id=c035] [remove=False]>
#     │           └── <(n29ea8e) Clause |  (FromClause) [remove=False]>
#     │               └── <(nfa9bc5) Expression |  (TableRef) [reftable=Loan] [table_reference_id=t004] [remove=False] [refalias=l]>
#     └── <(n1e016d) Clause |  (FromClause) [remove=False]>
#         └── <(ndd3395) Expression |  (TableRef) [reftable=Client] [table_reference_id=t006] [remove=False] [refalias=c]>
# --> Running reasoner and saving ontology...
# * Owlready2 * Running Pellet...
#     java -Xmx2000M -cp c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\antlr-3.2.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\antlr-runtime-3.2.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\aterm-java-1.6.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\commons-codec-1.6.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\httpclient-4.2.3.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\httpcore-4.2.2.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\jcl-over-slf4j-1.6.4.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\jena-arq-2.10.0.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\jena-core-2.10.0.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\jena-iri-0.9.5.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\jena-tdb-0.10.0.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\jgrapht-jdk1.5.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\log4j-1.2-api-2.19.0.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\log4j-api-2.19.0.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\log4j-core-2.19.0.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\owlapi-distribution-3.4.3-bin.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\pellet-2.3.1.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\slf4j-api-1.6.4.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\slf4j-log4j12-1.6.4.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\xercesImpl-2.10.0.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\xml-apis-1.4.01.jar pellet.Pellet realize --loader Jena --input-format N-Triples --infer-prop-values --ignore-imports C:\Users\NIPUN_~1\AppData\Local\Temp\tmp130ayz8w
# * Owlready2 * Pellet took 2.6065027713775635 seconds
# * Owlready * (NB: only changes on entities loaded in Python are shown, other changes are done but not listed)
# * Owlready2 * Running Pellet...
#     java -Xmx2000M -cp c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\antlr-3.2.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\antlr-runtime-3.2.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\aterm-java-1.6.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\commons-codec-1.6.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\httpclient-4.2.3.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\httpcore-4.2.2.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\jcl-over-slf4j-1.6.4.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\jena-arq-2.10.0.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\jena-core-2.10.0.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\jena-iri-0.9.5.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\jena-tdb-0.10.0.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\jgrapht-jdk1.5.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\log4j-1.2-api-2.19.0.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\log4j-api-2.19.0.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\log4j-core-2.19.0.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\owlapi-distribution-3.4.3-bin.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\pellet-2.3.1.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\slf4j-api-1.6.4.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\slf4j-log4j12-1.6.4.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\xercesImpl-2.10.0.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\xml-apis-1.4.01.jar pellet.Pellet realize --loader Jena --input-format N-Triples --infer-prop-values --ignore-imports C:\Users\NIPUN_~1\AppData\Local\Temp\tmp0hw4426x
# * Owlready * Adding relation aputv5e.n69eb16 hasParentNode aputv5e.n96774d
# * Owlready * Adding relation aputv5e.n69eb16 hasParentNode aputv5e.n0ced5f
# * Owlready * Adding relation aputv5e.n69eb16 hasParentNode aputv5e.s0ced5f
# * Owlready * Adding relation aputv5e.n69eb16 hasParentNode aputv5e.ncc9f27
# * Owlready * Adding relation aputv5e.n69eb16 hasChildNode aputv5e.n1fe705
# * Owlready * Adding relation aputv5e.n69eb16 hasChildNode aputv5e.n4dfe75
# * Owlready * Adding relation aputv5e.n69eb16 immediateChildNode aputv5e.n1fe705
# * Owlready * Adding relation aputv5e.s0ced5f hasChildNode aputv5e.n1fe705
# * Owlready * Adding relation aputv5e.s0ced5f hasChildNode aputv5e.n96774d
# * Owlready * Adding relation aputv5e.s0ced5f hasChildNode aputv5e.n1e016d
# * Owlready * Adding relation aputv5e.s0ced5f hasChildNode aputv5e.n0ced5f
# * Owlready * Adding relation aputv5e.s0ced5f hasChildNode aputv5e.n29ea8e
# * Owlready * Adding relation aputv5e.s0ced5f hasChildNode aputv5e.n4dfe75
# * Owlready * Adding relation aputv5e.s0ced5f hasChildNode aputv5e.nfa9bc5
# * Owlready * Adding relation aputv5e.s0ced5f hasChildNode aputv5e.n69eb16
# * Owlready * Adding relation aputv5e.s0ced5f hasChildNode aputv5e.ndd3395
# * Owlready * Adding relation aputv5e.s0ced5f hasChildNode aputv5e.ncc9f27
# * Owlready * Adding relation aputv5e.s0ced5f immediateChildNode aputv5e.n1e016d
# * Owlready * Adding relation aputv5e.s0ced5f immediateChildNode aputv5e.n0ced5f
# * Owlready * Adding relation aputv5e.nfa9bc5 hasParentNode aputv5e.n96774d
# * Owlready * Adding relation aputv5e.nfa9bc5 hasParentNode aputv5e.n29ea8e
# * Owlready * Adding relation aputv5e.nfa9bc5 hasParentNode aputv5e.n0ced5f
# * Owlready * Adding relation aputv5e.nfa9bc5 hasParentNode aputv5e.s0ced5f
# * Owlready * Adding relation aputv5e.nfa9bc5 hasParentNode aputv5e.ncc9f27
# * Owlready * Adding relation aputv5e.nfa9bc5 immediateParentNode aputv5e.n29ea8e
# * Owlready * Adding relation aputv5e.n1e016d hasParentNode aputv5e.s0ced5f
# * Owlready * Adding relation aputv5e.n1e016d immediateParentNode aputv5e.s0ced5f
# * Owlready * Adding relation aputv5e.n1e016d hasChildNode aputv5e.ndd3395
# * Owlready * Adding relation aputv5e.n1e016d immediateChildNode aputv5e.ndd3395
# * Owlready * Adding relation aputv5e.ncc9f27 hasParentNode aputv5e.n96774d
# * Owlready * Adding relation aputv5e.ncc9f27 hasParentNode aputv5e.n0ced5f
# * Owlready * Adding relation aputv5e.ncc9f27 hasParentNode aputv5e.s0ced5f
# * Owlready * Adding relation aputv5e.ncc9f27 hasChildNode aputv5e.n1fe705
# * Owlready * Adding relation aputv5e.ncc9f27 hasChildNode aputv5e.n29ea8e
# * Owlready * Adding relation aputv5e.ncc9f27 hasChildNode aputv5e.n4dfe75
# * Owlready * Adding relation aputv5e.ncc9f27 hasChildNode aputv5e.nfa9bc5
# * Owlready * Adding relation aputv5e.ncc9f27 hasChildNode aputv5e.n69eb16
# * Owlready * Adding relation aputv5e.n96774d hasParentNode aputv5e.n0ced5f
# * Owlready * Adding relation aputv5e.n96774d hasParentNode aputv5e.s0ced5f
# * Owlready * Adding relation aputv5e.n96774d immediateParentNode aputv5e.n0ced5f
# * Owlready * Adding relation aputv5e.n96774d hasChildNode aputv5e.n1fe705
# * Owlready * Adding relation aputv5e.n96774d hasChildNode aputv5e.n29ea8e
# * Owlready * Adding relation aputv5e.n96774d hasChildNode aputv5e.n4dfe75
# * Owlready * Adding relation aputv5e.n96774d hasChildNode aputv5e.nfa9bc5
# * Owlready * Adding relation aputv5e.n96774d hasChildNode aputv5e.n69eb16
# * Owlready * Adding relation aputv5e.n96774d hasChildNode aputv5e.ncc9f27
# * Owlready * Adding relation aputv5e.ndd3395 hasStatus apuf.RowTag
# * Owlready * Adding relation aputv5e.ndd3395 relatedPolicy aputv5e.p007
# * Owlready * Adding relation aputv5e.ndd3395 hasParentNode aputv5e.n1e016d
# * Owlready * Adding relation aputv5e.ndd3395 hasParentNode aputv5e.s0ced5f
# * Owlready * Adding relation aputv5e.ndd3395 immediateParentNode aputv5e.n1e016d
# * Owlready * Adding relation aputv5e.n0ced5f hasParentNode aputv5e.s0ced5f
# * Owlready * Adding relation aputv5e.n0ced5f immediateParentNode aputv5e.s0ced5f
# * Owlready * Adding relation aputv5e.n0ced5f hasChildNode aputv5e.n1fe705
# * Owlready * Adding relation aputv5e.n0ced5f hasChildNode aputv5e.n96774d
# * Owlready * Adding relation aputv5e.n0ced5f hasChildNode aputv5e.n29ea8e
# * Owlready * Adding relation aputv5e.n0ced5f hasChildNode aputv5e.n4dfe75
# * Owlready * Adding relation aputv5e.n0ced5f hasChildNode aputv5e.nfa9bc5
# * Owlready * Adding relation aputv5e.n0ced5f hasChildNode aputv5e.n69eb16
# * Owlready * Adding relation aputv5e.n0ced5f hasChildNode aputv5e.ncc9f27
# * Owlready * Adding relation aputv5e.n0ced5f immediateChildNode aputv5e.n96774d
# * Owlready * Adding relation aputv5e.n4dfe75 hasParentNode aputv5e.n1fe705
# * Owlready * Adding relation aputv5e.n4dfe75 hasParentNode aputv5e.n96774d
# * Owlready * Adding relation aputv5e.n4dfe75 hasParentNode aputv5e.n0ced5f
# * Owlready * Adding relation aputv5e.n4dfe75 hasParentNode aputv5e.s0ced5f
# * Owlready * Adding relation aputv5e.n4dfe75 hasParentNode aputv5e.n69eb16
# * Owlready * Adding relation aputv5e.n4dfe75 hasParentNode aputv5e.ncc9f27
# * Owlready * Adding relation aputv5e.n29ea8e hasParentNode aputv5e.n96774d
# * Owlready * Adding relation aputv5e.n29ea8e hasParentNode aputv5e.n0ced5f
# * Owlready * Adding relation aputv5e.n29ea8e hasParentNode aputv5e.s0ced5f
# * Owlready * Adding relation aputv5e.n29ea8e hasParentNode aputv5e.ncc9f27
# * Owlready * Adding relation aputv5e.n29ea8e hasChildNode aputv5e.nfa9bc5
# * Owlready * Adding relation aputv5e.n29ea8e immediateChildNode aputv5e.nfa9bc5
# * Owlready * Adding relation aputv5e.n1fe705 hasParentNode aputv5e.n96774d
# * Owlready * Adding relation aputv5e.n1fe705 hasParentNode aputv5e.n0ced5f
# * Owlready * Adding relation aputv5e.n1fe705 hasParentNode aputv5e.s0ced5f
# * Owlready * Adding relation aputv5e.n1fe705 hasParentNode aputv5e.n69eb16
# * Owlready * Adding relation aputv5e.n1fe705 hasParentNode aputv5e.ncc9f27
# * Owlready * Adding relation aputv5e.n1fe705 immediateParentNode aputv5e.n69eb16
# * Owlready * Adding relation aputv5e.n1fe705 hasChildNode aputv5e.n4dfe75
# * Owlready * Adding relation aputv5e.ndd3395 inferredRule aputv5e.rrp
# * Owlready * Adding relation aputv5e.ndd3395 inferredRule aputv5e.rrv
#     - Ontology saved to ../ontology_file/resolved_query_instances.rdf
# * Owlready2 * Pellet took 2.1410233974456787 seconds
# * Owlready * (NB: only changes on entities loaded in Python are shown, other changes are done but not listed)

# %%
status_set = instantiator.get_column_ref_instances() | instantiator.get_table_ref_instances()
print("Rule set: ", ", ".join(set([s.get("Rule") for s in status_set.values() if s.get("Rule") is not None])))
print("Policy set: ", ", ".join(set([s.get("Policy") for s in status_set.values() if s.get("Policy") is not None])))

pruner = ASTPruner(instantiator)
# 4. Prune the AST based on the ontology state
pruner.prune()
print(sql_op.to_sql())
# Out:
# Rule set:  rcp, rrp, rcv
# Policy set:  p006, p007, p005
# --- Starting AST Pruning Process ---
# Query before pruning: SELECT Client.client_id, Client.account_id, Client.district_id, Client.gender, Client.birth_date FROM "Client" WHERE birth_date LIKE '______01__'
# --> Stage 1: Pruning based on table statuses...
#     - TableRef 'n05217d' is RowTag. Adding condition to parent statement.
# where clauses: birth_date LIKE '______01__' | gender = 'male' | False
#     - TableRef 'n05217d' has RowTag. Adding condition to statement 's2622ce': gender = 'male'
# stmt_sqlglot_node: SELECT *, Client.client_id, Client.account_id, Client.district_id, Client.gender, Client.birth_date FROM "Client" WHERE birth_date LIKE '______01__' | <bound method Query.where of Select(
#   expressions=[
#     Star(),
#     Column(
#       this=Identifier(this=client_id, quoted=False),
#       table=Identifier(this=Client, quoted=False)),
#     Column(
#       this=Identifier(this=account_id, quoted=False),
#       table=Identifier(this=Client, quoted=False)),
#     Column(
#       this=Identifier(this=district_id, quoted=False),
#       table=Identifier(this=Client, quoted=False)),
#     Column(
#       this=Identifier(this=gender, quoted=False),
#       table=Identifier(this=Client, quoted=False)),
#     Column(
#       this=Identifier(this=birth_date, quoted=False),
#       table=Identifier(this=Client, quoted=False))],
#   from=From(
#     this=Table(
#       this=Identifier(this='Client', quoted=True))),
#   where=Where(
#     this=Like(
#       this=Column(
#         this=Identifier(this=birth_date, quoted=False)),
#       expression=Literal(this='______01__', is_string=True))))>
# --> Stage 2: Pruning based on column statuses...
#      - Initial violated column IDs: ['n5bda15', 'nad46af', 'n5e5311']
#      - Warning: Pruning reached max iterations. The AST may not be stable.
#      - Pruning complete (max iterations reached).
# SELECT
#   Client.gender,
#   Client.birth_date
# FROM "Client"
# WHERE
#   birth_date LIKE '______01__'

# %% [markdown]
# ---

# %%
sql_op = SqlglotOperator(query)
# view the sqlglot AST
sql_op.ast
# Out:
# Select(
#   expressions=[
#     Star()],
#   from=From(
#     this=Table(
#       this=Identifier(this='Client', quoted=True))),
#   where=Where(
#     this=Like(
#       this=Column(
#         this=Identifier(this=birth_date, quoted=False)),
#       expression=Literal(this='______01__', is_string=True))))

# %%
tree_op = ASTTreeOperator(sql_op)
print("\nCustom AST Tree:")
tree_op.pretty_print()
# Out:
# Custom AST Tree:
# └── <(s44f170) Statement |  (SelectStatement) [remove=False]>
#     ├── <(n44f170) Clause |  (SelectClause) [remove=False]>
#     │   └── <(n178884) Expression |  (Wildcard) [remove=False]>
#     ├── <(ncf73f2) Clause |  (FromClause) [remove=False]>
#     │   └── <(n6aba4a) Expression |  (TableRef) [reftable=Client] [remove=False]>
#     └── <(n5bf791) Clause |  (WhereClause) [remove=False] [value=birth_date LIKE '______01__']>
#         └── <(nf12277) Expression |  (Operator) [remove=False] [logics=False] [value=birth_date]>
#             ├── <(n25ad11) Expression |  (ColumnRef) [reftable=None, refcol=birth_date] [remove=False]>
#             └── <(n01b35d) Expression |  (Literal) [value=______01__] [remove=False] [value=______01__]>

# %%
onto_path = "../ontology_file/aputv5e.rdf"
output_path = "../ontology_file/resolved_query_instances.rdf"
agent_id = "a0012"

# 1. Create an instance of the class
instantiator = OntologyOperator(onto_path)

instantiator.instantiate_ontology(tree_op, agent_id)
tree_op.pretty_print()
# 3. Run the reasoner and save the ontology
instantiator.reason_and_save(output_path, save=True)
# Out:
# table entities: {'Card': 't007', 'Disposition': 't005', 'District': 't008', 'Order': 't001', 'Transaction': 't002', 'Account': 't003', 'Loan': 't004', 'Client': 't006'}
# column lookup: {('Card', 'type'): 'c026', ('Order', 'order_id'): 'c001', ('Order', 'account_to'): 'c004', ('Order', 'k_symbol'): 'c006', ('Transaction', 'trans_id'): 'c007', ('District', 'district_id'): 'c014', ('Account', 'district_id'): 'c014', ('Client', 'district_id'): 'c014', ('Loan', 'loan_id'): 'c016', ('Card', 'disp_id'): 'c020', ('Disposition', 'disp_id'): 'c020', ('Disposition', 'client_id'): 'c021', ('Client', 'client_id'): 'c021', ('Card', 'card_id'): 'c025', ('Transaction', 'k_symbol'): 'c032', ('Disposition', 'account_id'): 'c002', ('Order', 'account_id'): 'c002', ('Transaction', 'account_id'): 'c002', ('Account', 'account_id'): 'c002', ('Loan', 'account_id'): 'c002', ('Client', 'account_id'): 'c002', ('Order', 'amount'): 'c005', ('Transaction', 'date'): 'c008', ('Transaction', 'type'): 'c009', ('Account', 'frequency'): 'c015', ('Transaction', 'amount'): 'c031', ('Account', 'date'): 'c033', ('Loan', 'date'): 'c034', ('Loan', 'amount'): 'c035', ('Order', 'bank_to'): 'c003', ('Transaction', 'operation'): 'c010', ('Transaction', 'balance'): 'c011', ('Transaction', 'bank'): 'c012', ('Transaction', 'account'): 'c013', ('Loan', 'duration'): 'c017', ('Loan', 'payments'): 'c018', ('Loan', 'status'): 'c019', ('Disposition', 'type'): 'c022', ('Client', 'gender'): 'c023', ('Client', 'birth_date'): 'c024', ('Card', 'issued'): 'c027', ('District', 'name'): 'c028'}
# --> Instantiating ontology individuals...
# Adding new node with ID 'Loan.loan_id' under parent node 'SELECT * FROM "Loan" WHERE duration > 24'
# Adding new node with ID 'Loan.account_id' under parent node 'SELECT *, Loan.loan_id FROM "Loan" WHERE duration > 24'
# Adding new node with ID 'Loan.date' under parent node 'SELECT *, Loan.loan_id, Loan.account_id FROM "Loan" WHERE duration > 24'
# Adding new node with ID 'Loan.amount' under parent node 'SELECT *, Loan.loan_id, Loan.account_id, Loan.date FROM "Loan" WHERE duration > 24'
# Adding new node with ID 'Loan.duration' under parent node 'SELECT *, Loan.loan_id, Loan.account_id, Loan.date, Loan.amount FROM "Loan" WHERE duration > 24'
# Adding new node with ID 'Loan.payments' under parent node 'SELECT *, Loan.loan_id, Loan.account_id, Loan.date, Loan.amount, Loan.duration FROM "Loan" WHERE duration > 24'
# Adding new node with ID 'Loan.status' under parent node 'SELECT *, Loan.loan_id, Loan.account_id, Loan.date, Loan.amount, Loan.duration, Loan.payments FROM "Loan" WHERE duration > 24'
# SELECT Loan.loan_id, Loan.account_id, Loan.date, Loan.amount, Loan.duration, Loan.payments, Loan.status FROM "Loan" WHERE duration > 24
#  context_sources after WITH clauses: subquery_context : {} | in_context_sources: {}
# Initial in-context sources: {'Loan': {'type': 'base_table', 'name': 'Loan'}}
#  full context : {'Loan': {'type': 'base_table', 'name': 'Loan'}}
# Resolving column 'loan_id' in context of table alias 'Loan' | context_sources: {'Loan': {'type': 'base_table', 'name': 'Loan'}}
# Resolving column 'account_id' in context of table alias 'Loan' | context_sources: {'Loan': {'type': 'base_table', 'name': 'Loan'}}
# Resolving column 'date' in context of table alias 'Loan' | context_sources: {'Loan': {'type': 'base_table', 'name': 'Loan'}}
# Resolving column 'amount' in context of table alias 'Loan' | context_sources: {'Loan': {'type': 'base_table', 'name': 'Loan'}}
# Resolving column 'duration' in context of table alias 'Loan' | context_sources: {'Loan': {'type': 'base_table', 'name': 'Loan'}}
# Resolving column 'payments' in context of table alias 'Loan' | context_sources: {'Loan': {'type': 'base_table', 'name': 'Loan'}}
# Resolving column 'status' in context of table alias 'Loan' | context_sources: {'Loan': {'type': 'base_table', 'name': 'Loan'}}
# Resolving table '<(n8601dc) Expression |  (TableRef) [reftable=Loan] [remove=False]>' | context_sources: {'Loan': {'type': 'base_table', 'name': 'Loan'}}
# Resolving column 'duration' in context of table alias 'None' | context_sources: {'Loan': {'type': 'base_table', 'name': 'Loan'}}
#     - Instantiated 1 TableRefs and 8 ColumnRefs.
# └── <(s7ded4b) Statement |  (SelectStatement) [remove=False]>
#     ├── <(n7ded4b) Clause |  (SelectClause) [remove=False]>
#     │   ├── <(nac7838) Expression |  (ColumnRef) [reftable=Loan, refcol=loan_id] [table_reference_id=t004] [column_reference_id=c016] [remove=False]>
#     │   ├── <(n1a9809) Expression |  (ColumnRef) [reftable=Loan, refcol=account_id] [table_reference_id=t004] [column_reference_id=c002] [remove=False]>
#     │   ├── <(n0c2393) Expression |  (ColumnRef) [reftable=Loan, refcol=date] [table_reference_id=t004] [column_reference_id=c034] [remove=False]>
#     │   ├── <(nad315a) Expression |  (ColumnRef) [reftable=Loan, refcol=amount] [table_reference_id=t004] [column_reference_id=c035] [remove=False]>
#     │   ├── <(nd12967) Expression |  (ColumnRef) [reftable=Loan, refcol=duration] [table_reference_id=t004] [column_reference_id=c017] [remove=False]>
#     │   ├── <(n47c876) Expression |  (ColumnRef) [reftable=Loan, refcol=payments] [table_reference_id=t004] [column_reference_id=c018] [remove=False]>
#     │   └── <(nd60709) Expression |  (ColumnRef) [reftable=Loan, refcol=status] [table_reference_id=t004] [column_reference_id=c019] [remove=False]>
#     ├── <(nc9772c) Clause |  (FromClause) [remove=False]>
#     │   └── <(n8601dc) Expression |  (TableRef) [reftable=Loan] [table_reference_id=t004] [remove=False]>
#     └── <(n0b5eb0) Clause |  (WhereClause) [remove=False]>
#         └── <(n38b767) Expression |  (Operator) [remove=False] [logics=False] [value=duration]>
#             ├── <(n8f0888) Expression |  (ColumnRef) [reftable=Loan, refcol=duration] [table_reference_id=t004] [column_reference_id=c017] [remove=False]>
#             └── <(nc800ea) Expression |  (Literal) [value=24] [remove=False] [value=24]>
# --> Running reasoner and saving ontology...
# * Owlready2 * Running Pellet...
#     java -Xmx2000M -cp c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\antlr-3.2.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\antlr-runtime-3.2.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\aterm-java-1.6.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\commons-codec-1.6.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\httpclient-4.2.3.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\httpcore-4.2.2.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\jcl-over-slf4j-1.6.4.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\jena-arq-2.10.0.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\jena-core-2.10.0.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\jena-iri-0.9.5.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\jena-tdb-0.10.0.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\jgrapht-jdk1.5.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\log4j-1.2-api-2.19.0.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\log4j-api-2.19.0.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\log4j-core-2.19.0.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\owlapi-distribution-3.4.3-bin.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\pellet-2.3.1.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\slf4j-api-1.6.4.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\slf4j-log4j12-1.6.4.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\xercesImpl-2.10.0.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\xml-apis-1.4.01.jar pellet.Pellet realize --loader Jena --input-format N-Triples --infer-prop-values --ignore-imports C:\Users\NIPUN_~1\AppData\Local\Temp\tmpp8lrrz2c
# * Owlready2 * Pellet took 4.081799745559692 seconds
# * Owlready * (NB: only changes on entities loaded in Python are shown, other changes are done but not listed)
# * Owlready2 * Running Pellet...
#     java -Xmx2000M -cp c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\antlr-3.2.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\antlr-runtime-3.2.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\aterm-java-1.6.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\commons-codec-1.6.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\httpclient-4.2.3.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\httpcore-4.2.2.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\jcl-over-slf4j-1.6.4.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\jena-arq-2.10.0.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\jena-core-2.10.0.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\jena-iri-0.9.5.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\jena-tdb-0.10.0.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\jgrapht-jdk1.5.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\log4j-1.2-api-2.19.0.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\log4j-api-2.19.0.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\log4j-core-2.19.0.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\owlapi-distribution-3.4.3-bin.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\pellet-2.3.1.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\slf4j-api-1.6.4.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\slf4j-log4j12-1.6.4.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\xercesImpl-2.10.0.jar;c:\Users\nipun_qk4hy9e\miniconda3\envs\obaca_env\Lib\site-packages\owlready2\pellet\xml-apis-1.4.01.jar pellet.Pellet realize --loader Jena --input-format N-Triples --infer-prop-values --ignore-imports C:\Users\NIPUN_~1\AppData\Local\Temp\tmprg04ccfr
# * Owlready * Adding relation aputv5e.nc9772c hasParentNode aputv5e.s7ded4b
# * Owlready * Adding relation aputv5e.nc9772c immediateParentNode aputv5e.s7ded4b
# * Owlready * Adding relation aputv5e.nc9772c hasChildNode aputv5e.n8601dc
# * Owlready * Adding relation aputv5e.nc9772c immediateChildNode aputv5e.n8601dc
# * Owlready * Adding relation aputv5e.nac7838 hasParentNode aputv5e.s7ded4b
# * Owlready * Adding relation aputv5e.nac7838 hasParentNode aputv5e.n7ded4b
# * Owlready * Adding relation aputv5e.nac7838 immediateParentNode aputv5e.n7ded4b
# * Owlready * Adding relation aputv5e.nd60709 hasParentNode aputv5e.s7ded4b
# * Owlready * Adding relation aputv5e.nd60709 hasParentNode aputv5e.n7ded4b
# * Owlready * Adding relation aputv5e.nd60709 immediateParentNode aputv5e.n7ded4b
# * Owlready * Adding relation aputv5e.n1a9809 hasParentNode aputv5e.s7ded4b
# * Owlready * Adding relation aputv5e.n1a9809 hasParentNode aputv5e.n7ded4b
# * Owlready * Adding relation aputv5e.n1a9809 immediateParentNode aputv5e.n7ded4b
# * Owlready * Adding relation aputv5e.n7ded4b hasParentNode aputv5e.s7ded4b
# * Owlready * Adding relation aputv5e.n7ded4b immediateParentNode aputv5e.s7ded4b
# * Owlready * Adding relation aputv5e.n7ded4b hasChildNode aputv5e.n47c876
# * Owlready * Adding relation aputv5e.n7ded4b hasChildNode aputv5e.n0c2393
# * Owlready * Adding relation aputv5e.n7ded4b hasChildNode aputv5e.n1a9809
# * Owlready * Adding relation aputv5e.n7ded4b hasChildNode aputv5e.nd60709
# * Owlready * Adding relation aputv5e.n7ded4b hasChildNode aputv5e.nad315a
# * Owlready * Adding relation aputv5e.n7ded4b hasChildNode aputv5e.nac7838
# * Owlready * Adding relation aputv5e.n7ded4b hasChildNode aputv5e.nd12967
# * Owlready * Adding relation aputv5e.n7ded4b immediateChildNode aputv5e.n47c876
# * Owlready * Adding relation aputv5e.n7ded4b immediateChildNode aputv5e.n0c2393
# * Owlready * Adding relation aputv5e.n7ded4b immediateChildNode aputv5e.n1a9809
# * Owlready * Adding relation aputv5e.n7ded4b immediateChildNode aputv5e.nd60709
# * Owlready * Adding relation aputv5e.n7ded4b immediateChildNode aputv5e.nad315a
# * Owlready * Adding relation aputv5e.n7ded4b immediateChildNode aputv5e.nac7838
# * Owlready * Adding relation aputv5e.n7ded4b immediateChildNode aputv5e.nd12967
# * Owlready * Adding relation aputv5e.n0b5eb0 hasParentNode aputv5e.s7ded4b
# * Owlready * Adding relation aputv5e.n0b5eb0 immediateParentNode aputv5e.s7ded4b
# * Owlready * Adding relation aputv5e.n0b5eb0 hasChildNode aputv5e.n38b767
# * Owlready * Adding relation aputv5e.n0b5eb0 hasChildNode aputv5e.n8f0888
# * Owlready * Adding relation aputv5e.n0b5eb0 hasChildNode aputv5e.nc800ea
# * Owlready * Adding relation aputv5e.n0b5eb0 immediateChildNode aputv5e.n38b767
# * Owlready * Adding relation aputv5e.nad315a hasParentNode aputv5e.s7ded4b
# * Owlready * Adding relation aputv5e.nad315a hasParentNode aputv5e.n7ded4b
# * Owlready * Adding relation aputv5e.nad315a immediateParentNode aputv5e.n7ded4b
# * Owlready * Adding relation aputv5e.n38b767 hasParentNode aputv5e.s7ded4b
# * Owlready * Adding relation aputv5e.n38b767 hasParentNode aputv5e.n0b5eb0
# * Owlready * Adding relation aputv5e.n38b767 immediateParentNode aputv5e.n0b5eb0
# * Owlready * Adding relation aputv5e.n38b767 hasChildNode aputv5e.n8f0888
# * Owlready * Adding relation aputv5e.n38b767 hasChildNode aputv5e.nc800ea
# * Owlready * Adding relation aputv5e.n8601dc hasParentNode aputv5e.s7ded4b
# * Owlready * Adding relation aputv5e.n8601dc hasParentNode aputv5e.nc9772c
# * Owlready * Adding relation aputv5e.n8601dc immediateParentNode aputv5e.nc9772c
# * Owlready * Adding relation aputv5e.nd12967 hasParentNode aputv5e.s7ded4b
# * Owlready * Adding relation aputv5e.nd12967 hasParentNode aputv5e.n7ded4b
# * Owlready * Adding relation aputv5e.nd12967 immediateParentNode aputv5e.n7ded4b
# * Owlready * Adding relation aputv5e.n47c876 hasParentNode aputv5e.s7ded4b
# * Owlready * Adding relation aputv5e.n47c876 hasParentNode aputv5e.n7ded4b
# * Owlready * Adding relation aputv5e.n47c876 immediateParentNode aputv5e.n7ded4b
# * Owlready * Adding relation aputv5e.n0c2393 hasParentNode aputv5e.s7ded4b
# * Owlready * Adding relation aputv5e.n0c2393 hasParentNode aputv5e.n7ded4b
# * Owlready * Adding relation aputv5e.n0c2393 immediateParentNode aputv5e.n7ded4b
# * Owlready * Adding relation aputv5e.s7ded4b hasChildNode aputv5e.n38b767
# * Owlready * Adding relation aputv5e.s7ded4b hasChildNode aputv5e.n8f0888
# * Owlready * Adding relation aputv5e.s7ded4b hasChildNode aputv5e.n8601dc
# * Owlready * Adding relation aputv5e.s7ded4b hasChildNode aputv5e.n0b5eb0
# * Owlready * Adding relation aputv5e.s7ded4b hasChildNode aputv5e.n47c876
# * Owlready * Adding relation aputv5e.s7ded4b hasChildNode aputv5e.n0c2393
# * Owlready * Adding relation aputv5e.s7ded4b hasChildNode aputv5e.nd60709
# * Owlready * Adding relation aputv5e.s7ded4b hasChildNode aputv5e.nad315a
# * Owlready * Adding relation aputv5e.s7ded4b hasChildNode aputv5e.nd12967
# * Owlready * Adding relation aputv5e.s7ded4b hasChildNode aputv5e.nc9772c
# * Owlready * Adding relation aputv5e.s7ded4b hasChildNode aputv5e.n7ded4b
# * Owlready * Adding relation aputv5e.s7ded4b hasChildNode aputv5e.nc800ea
# * Owlready * Adding relation aputv5e.s7ded4b hasChildNode aputv5e.n1a9809
# * Owlready * Adding relation aputv5e.s7ded4b hasChildNode aputv5e.nac7838
# * Owlready * Adding relation aputv5e.s7ded4b immediateChildNode aputv5e.nc9772c
# * Owlready * Adding relation aputv5e.s7ded4b immediateChildNode aputv5e.n7ded4b
# * Owlready * Adding relation aputv5e.s7ded4b immediateChildNode aputv5e.n0b5eb0
# * Owlready * Adding relation aputv5e.nc800ea hasParentNode aputv5e.s7ded4b
# * Owlready * Adding relation aputv5e.nc800ea hasParentNode aputv5e.n38b767
# * Owlready * Adding relation aputv5e.nc800ea hasParentNode aputv5e.n0b5eb0
# * Owlready * Adding relation aputv5e.n8f0888 hasParentNode aputv5e.s7ded4b
# * Owlready * Adding relation aputv5e.n8f0888 hasParentNode aputv5e.n38b767
# * Owlready * Adding relation aputv5e.n8f0888 hasParentNode aputv5e.n0b5eb0
# * Owlready * Adding relation aputv5e.nac7838 hasStatus apuf.Violated
# * Owlready * Adding relation aputv5e.nac7838 relatedPolicy aputv5e.p005
# * Owlready * Adding relation aputv5e.nac7838 inferredRule aputv5e.rcp
# * Owlready * Adding relation aputv5e.n1a9809 hasStatus apuf.Violated
# * Owlready * Adding relation aputv5e.n1a9809 relatedPolicy aputv5e.p006
# * Owlready * Adding relation aputv5e.n1a9809 inferredRule aputv5e.rcv
# * Owlready * Adding relation aputv5e.nad315a hasStatus apuf.Violated
# * Owlready * Adding relation aputv5e.nad315a relatedPolicy aputv5e.p006
# * Owlready * Adding relation aputv5e.nad315a inferredRule aputv5e.rcv
# * Owlready * Adding relation aputv5e.n0c2393 hasStatus apuf.Violated
# * Owlready * Adding relation aputv5e.n0c2393 relatedPolicy aputv5e.p006
# * Owlready * Adding relation aputv5e.n0c2393 inferredRule aputv5e.rcv
#     - Ontology saved to ../ontology_file/resolved_query_instances.rdf
# * Owlready2 * Pellet took 2.687039375305176 seconds
# * Owlready * (NB: only changes on entities loaded in Python are shown, other changes are done but not listed)

# %%
print("Column reference node status: ", instantiator.get_column_ref_instances())
print("Table reference node status: ", instantiator.get_table_ref_instances())
# Out:
# Column reference node status:  {'n884309': {'Status': 'Violated', 'Policy': 'p006', 'Rule': 'rcv'}, 'n1c35af': {'Status': 'Aligned'}, 'n1d41bd': {'Status': 'Violated', 'Policy': 'p005', 'Rule': 'rcp'}, 'n10c450': {'Status': 'Aligned'}, 'n95b356': {'Status': 'Aligned'}, 'na6a970': {'Status': 'Aligned'}}
# Table reference node status:  {'n35e316': {'Status': 'Aligned'}, 'nbe6e21': {'Status': 'Aligned'}}

# %%
pruner = ASTPruner(instantiator)

# # 4. Prune the AST based on the ontology state
pruner.prune()

print(sql_op.to_sql())
# Out:
# --- Starting AST Pruning Process ---
# Query before pruning: SELECT Client.district_id, Client.client_id, Client.account_id, Client.gender, Client.birth_date FROM "Client" WHERE birth_date LIKE '______01__'
# --> Stage 1: Pruning based on table statuses...
# "gender = 'male'"
# --> Stage 2: Pruning based on column statuses...
#      - Warning: Pruning reached max iterations. The AST may not be stable.
#      - Pruning complete (max iterations reached).
# SELECT
#   Client.gender,
#   Client.birth_date
# FROM "Client"

# %%
instantiator.cleanup()
# Out:
# --> Cleanup: Attempting to delete 19 instances...
#     - Deleted instance: aputv5e.see11cf
#     - Deleted instance: aputv5e.nee11cf
#     - Deleted instance: aputv5e.nd50fe9
#     - Deleted instance: aputv5e.n21d175
#     - Deleted instance: aputv5e.n25edd1
#     - Deleted instance: aputv5e.nde7da3
#     - Deleted instance: aputv5e.nda7450
#     - Deleted instance: aputv5e.n35936d
#     - Deleted instance: aputv5e.n5154c5
#     - Deleted instance: aputv5e.n24158b
#     - Deleted instance: aputv5e.na6ce14
#     - Deleted instance: aputv5e.n8a780c
#     - Deleted instance: aputv5e.n246c0b
#     - Deleted instance: aputv5e.n19d806
#     - Deleted instance: aputv5e.n8935dd
#     - Deleted instance: aputv5e.na31466
#     - Deleted instance: aputv5e.n44e4ab
#     - Deleted instance: aputv5e.ndaaa56
#     - Deleted instance: aputv5e.n7958a5
# --> Cleanup complete. Successfully deleted 19 instances.

# %%
import sqlglot
from sqlglot import exp
from sqlglot.expressions import Expression

def sub_condition_exists(full_condition: str, sub_condition: str) -> bool:
    """
    Checks if a sub-condition is structurally present in a full condition
    by parsing both into an Abstract Syntax Tree (AST).

    Args:
        full_condition (str): The complete WHERE clause string.
        sub_condition (str): The sub-condition string to search for.

    Returns:
        True if a structurally identical sub-condition is found, False otherwise.
    """
    try:
        # Parse both conditions into their respective ASTs
        full_ast: Expression = sqlglot.parse_one(full_condition, read="where").this
        sub_ast: Expression = sqlglot.parse_one(sub_condition, read="where").this
    except Exception:
        # If either string is invalid SQL, they cannot match.
        return False

    # Walk the full AST and check if any node is structurally equal
    # to the sub-condition's AST. sqlglot's `==` operator on expressions
    # performs this structural comparison, ignoring whitespace and formatting.
    for node in full_ast.walk():
        if node == sub_ast:
            return True
            
    return False

# --- Example Usage ---
full_clause = "c.status = 'active' AND (l.amount > 5000 OR l.duration = 60)"
sub_clause_to_find = "l.amount>5000"

print(f"Does the sub-condition exist? -> {sub_condition_exists(full_clause, sub_clause_to_find)}")
# Expected Output: Does the sub-condition exist? -> True
# Out:
# Does the sub-condition exist? -> False

# %%
import re

def normalize_condition(condition: str) -> str:
    """
    Cleans up a single SQL condition string to make it comparable.
    - Converts to lowercase
    - Removes extra whitespace
    - Removes whitespace around operators
    """
    # Convert to lowercase and strip leading/trailing whitespace
    norm = condition.strip().lower()
    # Replace multiple spaces with a single space
    norm = re.sub(r'\s+', ' ', norm)
    # Remove whitespace around operators like =, >, <, etc.
    norm = re.sub(r'\s*([=<>!]+)\s*', r'\1', norm)
    return norm

def sub_condition_exists_no_parser(full_condition: str, sub_condition: str) -> bool:
    """
    Checks if a sub-condition exists in a full condition without parsing SQL.

    LIMITATIONS:
    - Only works reliably for conditions joined by AND.
    - Does not understand OR logic or complex nested parentheses.
    - Does not understand SQL semantics (e.g., BETWEEN).
    """
    if not sub_condition:
        return True
    if not full_condition:
        return False

    try:
        # Split the full condition by 'AND' (case-insensitive) and normalize each part
        full_parts = {
            normalize_condition(part)
            for part in re.split(r'\s+AND\s+', full_condition, flags=re.IGNORECASE)
        }

        # Split the sub-condition by 'AND' and normalize each part
        sub_parts = {
            normalize_condition(part)
            for part in re.split(r'\s+AND\s+', sub_condition, flags=re.IGNORECASE)
        }

        # Check if the set of sub-condition parts is a subset of the full condition parts
        return sub_parts.issubset(full_parts)
    except Exception:
        # If any regex or other error occurs, assume failure
        return False

# --- Example Usage ---
full_clause = "c.status = 'active' AND c.age > 30 AND c.gender = 'F'"

# Test 1: Simple case (should be True)
sub1 = "c.age > 30"
print(f"'{sub1}' exists? -> {sub_condition_exists_no_parser(full_clause, sub1)}")

# Test 2: Different order and whitespace (should be True)
sub2 = "c.gender='F'  AND  c.status = 'active'"
print(f"'{sub2}' exists? -> {sub_condition_exists_no_parser(full_clause, sub2)}")

# Test 3: Non-existent condition (should be False)
sub3 = "c.age < 20"
print(f"'{sub3}' exists? -> {sub_condition_exists_no_parser(full_clause, sub3)}")

# Test 4: A case where this method FAILS (involving OR)
full_clause_with_or = "c.status = 'active' OR c.age > 30"
sub4 = "c.age > 30"
print(f"\n--- LIMITATION EXAMPLE ---")
print(f"'{sub4}' in '{full_clause_with_or}'? -> {sub_condition_exists_no_parser(full_clause_with_or, sub4)}")
# This will incorrectly return False because the logic doesn't understand OR.
# Out:
# 'c.age > 30' exists? -> True
# 'c.gender='F'  AND  c.status = 'active'' exists? -> True
# 'c.age < 20' exists? -> False
#
# --- LIMITATION EXAMPLE ---
# 'c.age > 30' in 'c.status = 'active' OR c.age > 30'? -> False
